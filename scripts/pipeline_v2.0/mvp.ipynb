# %%
# %% [markdown]
# # Load and Inspect Preprocessed RNA-seq Datasets
#
# This notebook loads the AnnData files generated by Stage 2.5 of the pipeline
# (`preprocess_dataset_gene_ids.py`) and performs basic checks and inspections.

# %%
import scanpy as sc
import pandas as pd
import os
import numpy as np # For isnan check

# Configure pandas display options for better viewing
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# %%
# --- Configuration ---
# Directory containing the preprocessed h5ad files
preprocessed_dir = "/mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250502_211754/"

# List of dataset prefixes to load
dataset_names = ['adni', 'encode', 'gtex', 'mage'] # Add 'entex' if it was processed

# --- End Configuration ---

# %%
# Dictionary to hold the loaded AnnData objects
adata_dict = {}

print(f"Loading datasets from: {preprocessed_dir}\n")

for name in dataset_names:
    file_name = f"{name}_standardized_preprocessed.h5ad"
    file_path = os.path.join(preprocessed_dir, file_name)
    print(f"--- Loading {name.upper()} ---")
    print(f"File: {file_path}")
    if os.path.exists(file_path):
        try:
            adata_dict[name] = sc.read_h5ad(file_path)
            print(f"Successfully loaded {name.upper()} with shape {adata_dict[name].shape}")
        except Exception as e:
            print(f"ERROR: Could not load {file_path}: {e}")
    else:
        print(f"WARNING: File not found: {file_path}")
    print("-" * (len(name) + 14))

# %% [markdown]
# ## Inspect Loaded Datasets

# %%
if not adata_dict:
    print("No datasets were loaded successfully. Cannot perform inspection.")
else:
    for name, adata in adata_dict.items():
        print(f"\n\n========================= Inspecting: {name.upper()} =========================\n")

        # --- Basic Info ---
        print(f"--- AnnData Object Info ({name.upper()}) ---")
        print(adata)
        print("-" * 30)

        # --- Observations (.obs) ---
        print(f"\n--- Observations (.obs) Info ({name.upper()}) ---")
        print(f".obs shape: {adata.obs.shape}")
        print(f".obs columns: {adata.obs.columns.tolist()}")
        print("\n.obs.head():")
        print(adata.obs.head())
        # Check unique values for key categorical fields
        print("\nUnique values in key .obs columns:")
        for col in ['dataset', 'tissue', 'sex', 'data_type', 'expression_unit', 'tissue_ontology']:
            if col in adata.obs.columns:
                try:
                    unique_vals = adata.obs[col].unique()
                    # Handle categorical output nicely
                    if isinstance(unique_vals, pd.Categorical):
                         unique_vals = unique_vals.tolist()
                    # Limit display if too many unique values (e.g., tissue in GTEx)
                    display_vals = unique_vals[:10] if len(unique_vals) > 10 else unique_vals
                    ellipsis = "..." if len(unique_vals) > 10 else ""
                    print(f"  '{col}': {display_vals}{ellipsis} ({len(unique_vals)} total unique)")
                except Exception as e:
                    print(f"  Could not get unique values for '{col}': {e}")
            else:
                print(f"  '{col}': Column not found")
        # Check for missing values
        print("\nMissing values count in key .obs columns:")
        missing_data = {}
        for col in ['tissue', 'subject_id', 'dataset', 'sex', 'age', 'tissue_ontology']:
             if col in adata.obs.columns:
                # Count NaNs directly
                na_count = adata.obs[col].isna().sum()
                # Count empty strings '', being careful about NaNs
                is_empty_series = adata.obs[col].apply(lambda x: isinstance(x, str) and x.strip() == '')
                try:
                    empty_count = np.sum(is_empty_series.to_numpy(dtype=bool))
                except: # Fallback if conversion fails
                    empty_count = sum(1 for x in is_empty_series if x is True)
                total_missing = na_count + empty_count
                if total_missing > 0:
                    missing_data[col] = total_missing
        if missing_data:
            print(missing_data)
        else:
             print("  No missing/empty values found in checked key columns.")
        print("-" * 30)


        # --- Variables (.var) ---
        print(f"\n--- Variables (.var) Info ({name.upper()}) ---")
        print(f".var shape: {adata.var.shape}")
        print(f".var columns: {adata.var.columns.tolist()}")
        print(f".var index name: {adata.var.index.name}")
        print(f"First 5 var_names (index): {adata.var_names[:5].tolist()}")
        print("\n.var.head():")
        print(adata.var.head())
         # Check unique values for key categorical fields
        print("\nUnique values in key .var columns:")
        for col in ['gene_type', 'chromosome', 'mapping_source', 'mapping_confidence']:
            if col in adata.var.columns:
                try:
                    unique_vals = adata.var[col].unique()
                     # Handle categorical output nicely
                    if isinstance(unique_vals, pd.Categorical):
                         unique_vals = unique_vals.tolist()
                    display_vals = unique_vals[:10] if len(unique_vals) > 10 else unique_vals
                    ellipsis = "..." if len(unique_vals) > 10 else ""
                    print(f"  '{col}': {display_vals}{ellipsis} ({len(unique_vals)} total unique)")
                except Exception as e:
                    print(f"  Could not get unique values for '{col}': {e}")
            else:
                 print(f"  '{col}': Column not found")
        print("-" * 30)

        # --- Unstructured Annotation (.uns) ---
        print(f"\n--- Unstructured Annotation (.uns) Info ({name.upper()}) ---")
        print(f".uns keys: {list(adata.uns.keys())}")
        # Print specific .uns fields if they exist
        for key in ['dataset_info', 'gene_mapping_stats', 'metadata_validation', 'harmonized_gencode_version', 'harmonized_reference_genome']:
            if key in adata.uns:
                print(f"\n.uns['{key}']: ")
                # Pretty print dictionaries
                if isinstance(adata.uns[key], dict):
                    import json
                    print(json.dumps(adata.uns[key], indent=2, default=str)) # Use default=str for non-serializable
                else:
                    print(adata.uns[key])
        print("-" * 30)

print("\n========================= Inspection Complete =========================")
# Out:
# Loading datasets from: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250502_211754/
#
# --- Loading ADNI ---
# File: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250502_211754/adni_standardized_preprocessed.h5ad
# Successfully loaded ADNI with shape (650, 17991)
# ------------------
# --- Loading ENCODE ---
# File: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250502_211754/encode_standardized_preprocessed.h5ad
# Successfully loaded ENCODE with shape (7, 65586)
# --------------------
# --- Loading GTEX ---
# File: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250502_211754/gtex_standardized_preprocessed.h5ad
# Successfully loaded GTEX with shape (19616, 58988)
# ------------------
# --- Loading MAGE ---
# File: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250502_211754/mage_standardized_preprocessed.h5ad
# Successfully loaded MAGE with shape (731, 19428)
# ------------------
#
#
# ========================= Inspecting: ADNI =========================
#
# --- AnnData Object Info (ADNI) ---
# AnnData object with n_obs × n_vars = 650 × 17991
#     obs: 'sample_id', 'subject_id', 'dataset', 'data_type', 'expression_unit', 'tissue', 'platform', 'processing', 'sex', 'age', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence'
#     var: 'gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'original_gene_id', 'ensembl_id', 'mapping_confidence'
#     uns: 'dataset_info', 'gencode_version', 'gene_mapping_stats', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_validation', 'ontology_mappings', 'original_gencode_version', 'original_reference_genome', 'processing_date', 'reference_genome', 'subject_demographics'
# ------------------------------
#
# --- Observations (.obs) Info (ADNI) ---
# .obs shape: (650, 19)
# .obs columns: ['sample_id', 'subject_id', 'dataset', 'data_type', 'expression_unit', 'tissue', 'platform', 'processing', 'sex', 'age', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence']
#
# .obs.head():
#                                                                          sample_id  subject_id dataset   data_type       expression_unit tissue                            platform   processing      sex age species species_ontology tissue_original tissue_ontology data_type_original assay_ontology age_original developmental_stage_ontology tissue_ontology_confidence
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413    ADNI  Microarray  Normalized intensity  blood  Affymetrix Human Genome U219 Array  gencode_v24  unknown       human   NCBITaxon:9606           blood  UBERON:0000178         Microarray                                                                              medium
# 002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729    ADNI  Microarray  Normalized intensity  blood  Affymetrix Human Genome U219 Array  gencode_v24  unknown       human   NCBITaxon:9606           blood  UBERON:0000178         Microarray                                                                              medium
# 002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155    ADNI  Microarray  Normalized intensity  blood  Affymetrix Human Genome U219 Array  gencode_v24  unknown       human   NCBITaxon:9606           blood  UBERON:0000178         Microarray                                                                              medium
# 002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261    ADNI  Microarray  Normalized intensity  blood  Affymetrix Human Genome U219 Array  gencode_v24  unknown       human   NCBITaxon:9606           blood  UBERON:0000178         Microarray                                                                              medium
# 002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268    ADNI  Microarray  Normalized intensity  blood  Affymetrix Human Genome U219 Array  gencode_v24  unknown       human   NCBITaxon:9606           blood  UBERON:0000178         Microarray                                                                              medium
#
# Unique values in key .obs columns:
#   'dataset': ['ADNI'] (1 total unique)
#   'tissue': ['blood'] (1 total unique)
#   'sex': ['unknown'] (1 total unique)
#   'data_type': ['Microarray'] (1 total unique)
#   'expression_unit': ['Normalized intensity'] (1 total unique)
#   'tissue_ontology': ['UBERON:0000178'] (1 total unique)
#
# Missing values count in key .obs columns:
# {'age': np.int64(650)}
# ------------------------------
#
# --- Variables (.var) Info (ADNI) ---
# .var shape: (17991, 9)
# .var columns: ['gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'original_gene_id', 'ensembl_id', 'mapping_confidence']
# .var index name: None
# First 5 var_names (index): ['ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000938']
#
# .var.head():
#                          gene_id        original_ids gene_name       gene_type chromosome     mapping_source original_gene_id       ensembl_id mapping_confidence
# ENSG00000000003  ENSG00000000003  ENSG00000000003.14    TSPAN6  protein_coding       chrX  reference_mapping  ENSG00000000003  ENSG00000000003               high
# ENSG00000000005  ENSG00000000005   ENSG00000000005.5      TNMD  protein_coding       chrX  reference_mapping  ENSG00000000005  ENSG00000000005               high
# ENSG00000000419  ENSG00000000419  ENSG00000000419.12      DPM1  protein_coding      chr20  reference_mapping  ENSG00000000419  ENSG00000000419               high
# ENSG00000000457  ENSG00000000457  ENSG00000000457.13     SCYL3  protein_coding       chr1  reference_mapping  ENSG00000000457  ENSG00000000457               high
# ENSG00000000938  ENSG00000000938  ENSG00000000938.12       FGR  protein_coding       chr1  reference_mapping  ENSG00000000938  ENSG00000000938               high
#
# Unique values in key .var columns:
#   'gene_type': ['protein_coding', 'unitary_pseudogene', 'transcribed_unprocessed_pseudogene', 'antisense', 'processed_pseudogene', 'unprocessed_pseudogene', 'lincRNA', 'transcribed_processed_pseudogene', 'transcribed_unitary_pseudogene', 'polymorphic_pseudogene']... (23 total unique)
#   'chromosome': ['chrX', 'chr20', 'chr1', 'chr6', 'chr3', 'chr7', 'chr12', 'chr11', 'chr4', 'chr17']... (24 total unique)
#   'mapping_source': ['reference_mapping'] (1 total unique)
#   'mapping_confidence': ['high'] (1 total unique)
# ------------------------------
#
# --- Unstructured Annotation (.uns) Info (ADNI) ---
# .uns keys: ['dataset_info', 'gencode_version', 'gene_mapping_stats', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_validation', 'ontology_mappings', 'original_gencode_version', 'original_reference_genome', 'processing_date', 'reference_genome', 'subject_demographics']
#
# .uns['dataset_info']:
# {
#   "assay_ontology": "EFO:0002695",
#   "data_type": "microarray",
#   "description": "Alzheimer's Disease Neuroimaging Initiative microarray data with demographic information",
#   "expression_unit": "quantile normalized microarray counts",
#   "gencode_version": "24",
#   "platform": "Affymetrix Human Genome U219 Array",
#   "reference": "https://pmc.ncbi.nlm.nih.gov/articles/PMC7541709/",
#   "reference_genome": "hg38",
#   "source": "ADNI",
#   "version": "April 2025"
# }
#
# .uns['gene_mapping_stats']:
# {
#   "mapped_genes": "17991",
#   "mapping_percentage": 100.0,
#   "mapping_source": "reference_mapping",
#   "total_genes": "17991"
# }
#
# .uns['metadata_validation']:
# {
#   "dataset": "ADNI",
#   "missing_fields": "[]",
#   "missing_values": {},
#   "sample_count": "650",
#   "unmapped_ages": "[]",
#   "unmapped_assays": "['Microarray']",
#   "unmapped_tissues": "[]",
#   "validation_status": "warning"
# }
#
# .uns['harmonized_gencode_version']:
# 24
#
# .uns['harmonized_reference_genome']:
# hg38
# ------------------------------
#
#
# ========================= Inspecting: ENCODE =========================
#
# --- AnnData Object Info (ENCODE) ---
# AnnData object with n_obs × n_vars = 7 × 65586
#     obs: 'original_sample_id', 'cell_line', 'description', 'tissue', 'disease', 'cell_type', 'sex', 'organism', 'age', 'ethnicity', 'subject_id', 'geo_id', 'nucleic_acid_type', 'depletion', 'size_range', 'strand_specificity', 'cell_type_info', 'extraction_method', 'data_type', 'expression_unit', 'assay', 'dataset', 'sample_id', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence'
#     var: 'original_id_from_input', 'original_id_from_source', 'ensembl_id', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'mapping_confidence', 'gene_id'
#     uns: 'assay_ontology', 'cell_type_info', 'data_type', 'dataset_info', 'gencode_version', 'gene_mapping_stats', 'genome_info', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_sources', 'metadata_validation', 'ontology_mappings', 'platform', 'processing_date', 'reference_genome', 'rna_seq_protocol'
# ------------------------------
#
# --- Observations (.obs) Info (ENCODE) ---
# .obs shape: (7, 32)
# .obs columns: ['original_sample_id', 'cell_line', 'description', 'tissue', 'disease', 'cell_type', 'sex', 'organism', 'age', 'ethnicity', 'subject_id', 'geo_id', 'nucleic_acid_type', 'depletion', 'size_range', 'strand_specificity', 'cell_type_info', 'extraction_method', 'data_type', 'expression_unit', 'assay', 'dataset', 'sample_id', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence']
#
# .obs.head():
#             original_sample_id cell_line                                     description       tissue                          disease    cell_type     sex organism age ethnicity   subject_id        geo_id    nucleic_acid_type depletion size_range         strand_specificity                                     cell_type_info extraction_method data_type expression_unit                    assay dataset sample_id species species_ontology tissue_original tissue_ontology data_type_original assay_ontology age_original developmental_stage_ontology tissue_ontology_confidence
# _sample_id
# ENCFF244DNJ        ENCFF244DNJ      A549                  Human lung carcinoma cell line         lung                   adenocarcinoma   epithelial    male    human  58  European  ENCDO451RUA  SAMN05733878  polyadenylated mRNA      rRNA       >200  Strand-specific (reverse)  {'anatomical_entity_id': 'UBERON:0002048', 'ce...        polyA_plus   RNA-seq             TPM                           ENCODE             human   NCBITaxon:9606            lung  UBERON:0002048            RNA-seq    EFO:0009922           58               HsapDv:0000087                     medium
# ENCFF685WJV        ENCFF685WJV     Caki2     Human kidney clear cell carcinoma cell line       kidney  clear cell renal cell carcinoma   epithelial    male    human  69  European  ENCDO869AAI  SAMN04284635                  RNA      rRNA       >200  Strand-specific (reverse)  {'anatomical_entity_id': 'UBERON:0002113', 'ce...                     RNA-seq             TPM  RNA-seq (total RNA-seq)  ENCODE             human   NCBITaxon:9606          kidney  UBERON:0002113            RNA-seq    EFO:0009922           69               HsapDv:0000087                     medium
# ENCFF640FPG        ENCFF640FPG   GM23248                 Human skin fibroblast cell line         skin                           normal   Fibroblast    male    human  53  European  ENCDO467QPX  SAMN04284514                  RNA      rRNA       >200  Strand-specific (reverse)  {'anatomical_entity_id': 'UBERON:0002097', 'ce...                     RNA-seq             TPM  RNA-seq (total RNA-seq)  ENCODE             human   NCBITaxon:9606            skin  UBERON:0002097            RNA-seq    EFO:0009922           53               HsapDv:0000087                     medium
# ENCFF863QWG        ENCFF863QWG     HepG2  Human liver hepatocellular carcinoma cell line        liver         hepatocellular carcinoma   epithelial    male    human  15  European  ENCDO886MPB  SAMN04284581                  RNA      rRNA       >200  Strand-specific (reverse)  {'anatomical_entity_id': 'UBERON:0002107', 'ce...                     RNA-seq             TPM  RNA-seq (total RNA-seq)  ENCODE             human   NCBITaxon:9606           liver  UBERON:0002107            RNA-seq    EFO:0009922           15               HsapDv:0000086                     medium
# ENCFF171FQU        ENCFF171FQU      K562    Human chronic myelogenous leukemia cell line  bone marrow     chronic myelogenous leukemia  lymphoblast  female    human  53   unknown  ENCDO000AAL  SAMN04284550                  RNA      rRNA       >200  Strand-specific (reverse)  {'anatomical_entity_id': 'UBERON:0002371', 'ce...                     RNA-seq             TPM  RNA-seq (total RNA-seq)  ENCODE             human   NCBITaxon:9606     bone marrow  UBERON:0002371            RNA-seq    EFO:0009922           53               HsapDv:0000087                     medium
#
# Unique values in key .obs columns:
#   'dataset': ['ENCODE'] (1 total unique)
#   'tissue': ['lung', 'kidney', 'skin', 'liver', 'bone marrow', 'pancreas'] (6 total unique)
#   'sex': ['male', 'female'] (2 total unique)
#   'data_type': ['RNA-seq'] (1 total unique)
#   'expression_unit': ['TPM'] (1 total unique)
#   'tissue_ontology': ['UBERON:0002048', 'UBERON:0002113', 'UBERON:0002097', 'UBERON:0002107', 'UBERON:0002371', 'UBERON:0001264'] (6 total unique)
#
# Missing values count in key .obs columns:
# {'age': np.int64(1)}
# ------------------------------
#
# --- Variables (.var) Info (ENCODE) ---
# .var shape: (65586, 9)
# .var columns: ['original_id_from_input', 'original_id_from_source', 'ensembl_id', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'mapping_confidence', 'gene_id']
# .var index name: feature_id
# First 5 var_names (index): ['ENSG00000166619', 'ENTREZ:12954', 'ENTREZ:12956', 'ENTREZ:12958', 'ENTREZ:12960']
#
# .var.head():
#                 original_id_from_input original_id_from_source       ensembl_id gene_name       gene_type chromosome                 mapping_source mapping_confidence          gene_id
# feature_id
# ENSG00000166619                  10904                   10904  ENSG00000166619     BLCAP  protein_coding      chr20  encode_mapping -> ref_numeric               high  ENSG00000166619
# ENTREZ:12954                     12954                   12954     ENTREZ:12954                   unknown                            encode_mapping                low     ENTREZ:12954
# ENTREZ:12956                     12956                   12956     ENTREZ:12956                   unknown                            encode_mapping                low     ENTREZ:12956
# ENTREZ:12958                     12958                   12958     ENTREZ:12958                   unknown                            encode_mapping                low     ENTREZ:12958
# ENTREZ:12960                     12960                   12960     ENTREZ:12960                   unknown                            encode_mapping                low     ENTREZ:12960
#
# Unique values in key .var columns:
#   'gene_type': ['protein_coding', 'unknown', 'processed_transcript', 'processed_pseudogene', 'unprocessed_pseudogene', 'snRNA', 'IG_V_pseudogene', 'IG_D_gene', 'TR_J_gene', 'TR_D_gene']... (46 total unique)
#   'chromosome': ['chr20', '', 'chr1', 'chr3', 'chr17', 'chr5', 'chr22', 'chr7', 'chr16', 'chr11']... (27 total unique)
#   'mapping_source': ['encode_mapping -> ref_numeric', 'encode_mapping', 'unmapped', 'spike_in'] (4 total unique)
#   'mapping_confidence': ['high', 'low', 'none'] (3 total unique)
# ------------------------------
#
# --- Unstructured Annotation (.uns) Info (ENCODE) ---
# .uns keys: ['assay_ontology', 'cell_type_info', 'data_type', 'dataset_info', 'gencode_version', 'gene_mapping_stats', 'genome_info', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_sources', 'metadata_validation', 'ontology_mappings', 'platform', 'processing_date', 'reference_genome', 'rna_seq_protocol']
#
# .uns['dataset_info']:
# {
#   "cell_lines": {
#     "A549": {
#       "age": "58",
#       "cell_type": "epithelial",
#       "cell_type_info": {
#         "anatomical_entity_id": "UBERON:0002048",
#         "cell_type_id": "CL:0000066"
#       },
#       "depletion": "rRNA",
#       "description": "Human lung carcinoma cell line",
#       "disease": "adenocarcinoma",
#       "ethnicity": "European",
#       "geo_id": "SAMN05733878",
#       "nucleic_acid_type": "polyadenylated mRNA",
#       "organism": "human",
#       "sex": "male",
#       "size_range": ">200",
#       "strand_specificity": "Strand-specific (reverse)",
#       "subject_id": "ENCDO451RUA",
#       "tissue": "lung"
#     },
#     "Caki2": {
#       "age": "69",
#       "assay": "RNA-seq (total RNA-seq)",
#       "cell_type": "epithelial",
#       "cell_type_info": {
#         "anatomical_entity_id": "UBERON:0002113",
#         "cell_type_id": "CL:0000066"
#       },
#       "depletion": "rRNA",
#       "description": "Human kidney clear cell carcinoma cell line",
#       "disease": "clear cell renal cell carcinoma",
#       "ethnicity": "European",
#       "geo_id": "SAMN04284635",
#       "nucleic_acid_type": "RNA",
#       "organism": "human",
#       "sex": "male",
#       "size_range": ">200",
#       "strand_specificity": "Strand-specific (reverse)",
#       "subject_id": "ENCDO869AAI",
#       "tissue": "kidney"
#     },
#     "GM23248": {
#       "age": "53",
#       "assay": "RNA-seq (total RNA-seq)",
#       "cell_type": "Fibroblast",
#       "cell_type_info": {
#         "anatomical_entity_id": "UBERON:0002097",
#         "cell_type_id": "CL:0000057"
#       },
#       "depletion": "rRNA",
#       "description": "Human skin fibroblast cell line",
#       "disease": "normal",
#       "ethnicity": "European",
#       "geo_id": "SAMN04284514",
#       "nucleic_acid_type": "RNA",
#       "organism": "human",
#       "sex": "male",
#       "size_range": ">200",
#       "strand_specificity": "Strand-specific (reverse)",
#       "subject_id": "ENCDO467QPX",
#       "tissue": "skin"
#     },
#     "HepG2": {
#       "age": "15",
#       "assay": "RNA-seq (total RNA-seq)",
#       "cell_type": "epithelial",
#       "cell_type_info": {
#         "anatomical_entity_id": "UBERON:0002107",
#         "cell_type_id": "CL:0000066"
#       },
#       "depletion": "rRNA",
#       "description": "Human liver hepatocellular carcinoma cell line",
#       "disease": "hepatocellular carcinoma",
#       "ethnicity": "European",
#       "geo_id": "SAMN04284581",
#       "nucleic_acid_type": "RNA",
#       "organism": "human",
#       "sex": "male",
#       "size_range": ">200",
#       "strand_specificity": "Strand-specific (reverse)",
#       "subject_id": "ENCDO886MPB",
#       "tissue": "liver"
#     },
#     "K562": {
#       "age": "53",
#       "assay": "RNA-seq (total RNA-seq)",
#       "cell_type": "lymphoblast",
#       "cell_type_info": {
#         "anatomical_entity_id": "UBERON:0002371",
#         "cell_type_id": "CL:0000945"
#       },
#       "depletion": "rRNA",
#       "description": "Human chronic myelogenous leukemia cell line",
#       "disease": "chronic myelogenous leukemia",
#       "ethnicity": "unknown",
#       "geo_id": "SAMN04284550",
#       "nucleic_acid_type": "RNA",
#       "organism": "human",
#       "sex": "female",
#       "size_range": ">200",
#       "strand_specificity": "Strand-specific (reverse)",
#       "subject_id": "ENCDO000AAL",
#       "tissue": "bone marrow"
#     },
#     "NCI-H460": {
#       "age": "",
#       "assay": "RNA-seq (total RNA-seq)",
#       "cell_type": "epithelial",
#       "cell_type_info": {
#         "anatomical_entity_id": "UBERON:0002048",
#         "cell_type_id": "CL:0000066"
#       },
#       "depletion": "rRNA",
#       "description": "Human lung large cell carcinoma cell line",
#       "disease": "large cell lung carcinoma",
#       "ethnicity": "unknown",
#       "geo_id": "SAMN07791353",
#       "nucleic_acid_type": "RNA",
#       "organism": "human",
#       "sex": "male",
#       "size_range": ">200",
#       "strand_specificity": "Strand-specific (reverse)",
#       "subject_id": "ENCDO105AAA",
#       "tissue": "lung"
#     },
#     "Panc1": {
#       "age": "56",
#       "assay": "RNA-seq (total RNA-seq)",
#       "cell_type": "ductal cell",
#       "cell_type_info": {
#         "anatomical_entity_id": "UBERON:0001264",
#         "cell_type_id": "CL:0000068"
#       },
#       "depletion": "rRNA",
#       "description": "Human pancreatic ductal carcinoma cell line",
#       "disease": "pancreatic carcinoma",
#       "ethnicity": "European",
#       "geo_id": "SAMN05733879",
#       "nucleic_acid_type": "RNA",
#       "organism": "human",
#       "sex": "male",
#       "size_range": ">200",
#       "strand_specificity": "Strand-specific (reverse)",
#       "subject_id": "ENCDO845WKR",
#       "tissue": "pancreas"
#     }
#   },
#   "data_repository": "[{\"name\": \"ENCODE Project\", \"url\": \"https://www.encodeproject.org/\"}]",
#   "project": "ENCODE"
# }
#
# .uns['gene_mapping_stats']:
# {
#   "mapped_genes": "43086",
#   "mapping_percentage": 65.69389808800659,
#   "mapping_sources": {
#     "encode_mapping": "42707",
#     "encode_mapping -> ref_numeric": "282",
#     "spike_in": "97",
#     "unmapped": "22500"
#   },
#   "total_genes": "65586",
#   "unmapped_count": "22500"
# }
#
# .uns['metadata_validation']:
# {
#   "dataset": "ENCODE",
#   "missing_fields": "[]",
#   "missing_values": {
#     "assay": "1",
#     "extraction_method": "6"
#   },
#   "sample_count": "7",
#   "unmapped_ages": "[]",
#   "unmapped_assays": "[]",
#   "unmapped_tissues": "[]",
#   "validation_status": "warning"
# }
#
# .uns['harmonized_gencode_version']:
# 24
#
# .uns['harmonized_reference_genome']:
# hg38
# ------------------------------
#
#
# ========================= Inspecting: GTEX =========================
#
# --- AnnData Object Info (GTEX) ---
# AnnData object with n_obs × n_vars = 19616 × 58988
#     obs: 'SMATSSCR', 'SMCENTER', 'SMPTHNTS', 'rna_integrity_number', 'broad_tissue', 'tissue', 'SMUBRID', 'ischemic_time', 'SMTSPAX', 'array_batch', 'SMNABTCHT', 'SMNABTCHD', 'batch', 'SMGEBTCHD', 'SMGEBTCHT', 'ANALYTE_TYPE', 'SMAFRZE', 'SMGTC', 'SMRDTTL', 'SMALTTL', 'SMALTALG', 'SMSUPALG', 'SMRDLGTH', 'SMVQCFL', 'SMLMAPQ', 'SMUMPRD', 'SMUNPDRD', 'SMMPPD', 'SMMAPRT', 'SMMPPDUN', 'SMUNMPRT', 'SMMPDP', 'SMDPMPRT', 'SMMPPDXG', 'SMMPDPXG', 'SMDPRTXG', 'SMCHMRD', 'SMCHMRT', 'SMMPPDPR', 'SMMPHQRD', 'SMMPHQRT', 'SMMPLQRD', 'SMSPLTRT', 'SME1MPRD', 'SME2MPRD', 'SME1MPRT', 'SME2MPRT', 'SME1MMB', 'SME2MMB', 'SME1TTLB', 'SME2TTLB', 'SME1MMRT', 'SME2MMRT', 'SMTTLMM', 'SMTTLB', 'SMBSMMRT', 'SMESTLBS', 'SMEXNCRD', 'SMEXNCRT', 'SMEXPEFF', 'SMNTRNRD', 'SMNTRNRT', 'SMNTRARD', 'SMNTRART', 'SMNTERRD', 'SMNTERRT', 'SMAMBRD', 'SMAMBRT', 'SMNTEXC', 'SMDSCRT', 'SMEXNCRTHQ', 'SMNTRNRTHQ', 'SMNTRARTHQ', 'SMNTERRTHQ', 'SMAMBRTHQ', 'SME1SNSE', 'SME2SNSE', 'SME1ANTI', 'SME2ANTI', 'SME1PCTS', 'SME2PCTS', 'SMGNSDTC', 'SMRRNARD', 'SMRRNART', 'SMMFLGTH', 'SMSFLGTH', 'SMMDFLGTH', 'SMSMFLGTH', 'SMFGCMN', 'SMFGCSD', 'SMFGCSK', 'SMFGCKT', 'SM3PBMN', 'SM3PBSD', 'SM3PBMD', 'SM3PB25P', 'SM3PB75P', 'SM3PBSDM', 'SM3PBGN', 'SMMDMNCV', 'SMMDCVSD', 'SMMDCVCV', 'SMEXCVMD', 'SMEXCVMAD', 'SMMNCV', 'SMUVCRD', 'SMUVCRT', 'SMSHRTRD', 'SMSHRTRT', 'SMSMRDHQ', 'SMSMRTHQ', 'SMPRERDHQ', 'SMPRERTHQ', 'SMSMGNDT', 'SMPREGNDT', 'SMRDLNMN', 'SMRDLNMD', 'SMRDLNSD', 'subject_id', 'sex', 'age', 'DTHHRDY', 'dataset', 'original_sample_id', 'data_type', 'expression_unit', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'original_obs_sample_id', 'tissue_ontology_confidence'
#     var: 'gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'original_gene_id', 'ensembl_id', 'mapping_confidence'
#     uns: 'dataset_info', 'dataset_version', 'gencode_version', 'gene_mapping_stats', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_sources', 'metadata_validation', 'original_gencode_version', 'original_reference_genome', 'processing_date', 'reference_genome', 'rna_seq_protocol'
# ------------------------------
#
# --- Observations (.obs) Info (GTEX) ---
# .obs shape: (19616, 136)
# .obs columns: ['SMATSSCR', 'SMCENTER', 'SMPTHNTS', 'rna_integrity_number', 'broad_tissue', 'tissue', 'SMUBRID', 'ischemic_time', 'SMTSPAX', 'array_batch', 'SMNABTCHT', 'SMNABTCHD', 'batch', 'SMGEBTCHD', 'SMGEBTCHT', 'ANALYTE_TYPE', 'SMAFRZE', 'SMGTC', 'SMRDTTL', 'SMALTTL', 'SMALTALG', 'SMSUPALG', 'SMRDLGTH', 'SMVQCFL', 'SMLMAPQ', 'SMUMPRD', 'SMUNPDRD', 'SMMPPD', 'SMMAPRT', 'SMMPPDUN', 'SMUNMPRT', 'SMMPDP', 'SMDPMPRT', 'SMMPPDXG', 'SMMPDPXG', 'SMDPRTXG', 'SMCHMRD', 'SMCHMRT', 'SMMPPDPR', 'SMMPHQRD', 'SMMPHQRT', 'SMMPLQRD', 'SMSPLTRT', 'SME1MPRD', 'SME2MPRD', 'SME1MPRT', 'SME2MPRT', 'SME1MMB', 'SME2MMB', 'SME1TTLB', 'SME2TTLB', 'SME1MMRT', 'SME2MMRT', 'SMTTLMM', 'SMTTLB', 'SMBSMMRT', 'SMESTLBS', 'SMEXNCRD', 'SMEXNCRT', 'SMEXPEFF', 'SMNTRNRD', 'SMNTRNRT', 'SMNTRARD', 'SMNTRART', 'SMNTERRD', 'SMNTERRT', 'SMAMBRD', 'SMAMBRT', 'SMNTEXC', 'SMDSCRT', 'SMEXNCRTHQ', 'SMNTRNRTHQ', 'SMNTRARTHQ', 'SMNTERRTHQ', 'SMAMBRTHQ', 'SME1SNSE', 'SME2SNSE', 'SME1ANTI', 'SME2ANTI', 'SME1PCTS', 'SME2PCTS', 'SMGNSDTC', 'SMRRNARD', 'SMRRNART', 'SMMFLGTH', 'SMSFLGTH', 'SMMDFLGTH', 'SMSMFLGTH', 'SMFGCMN', 'SMFGCSD', 'SMFGCSK', 'SMFGCKT', 'SM3PBMN', 'SM3PBSD', 'SM3PBMD', 'SM3PB25P', 'SM3PB75P', 'SM3PBSDM', 'SM3PBGN', 'SMMDMNCV', 'SMMDCVSD', 'SMMDCVCV', 'SMEXCVMD', 'SMEXCVMAD', 'SMMNCV', 'SMUVCRD', 'SMUVCRT', 'SMSHRTRD', 'SMSHRTRT', 'SMSMRDHQ', 'SMSMRTHQ', 'SMPRERDHQ', 'SMPRERTHQ', 'SMSMGNDT', 'SMPREGNDT', 'SMRDLNMN', 'SMRDLNMD', 'SMRDLNSD', 'subject_id', 'sex', 'age', 'DTHHRDY', 'dataset', 'original_sample_id', 'data_type', 'expression_unit', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'original_obs_sample_id', 'tissue_ontology_confidence']
#
# .obs.head():
#                                SMATSSCR SMCENTER SMPTHNTS  rna_integrity_number broad_tissue                                    tissue         SMUBRID  ischemic_time  SMTSPAX array_batch                                 SMNABTCHT SMNABTCHD        batch SMGEBTCHD  SMGEBTCHT   ANALYTE_TYPE SMAFRZE SMGTC      SMRDTTL      SMALTTL     SMALTALG  SMSUPALG  SMRDLGTH     SMVQCFL      SMLMAPQ      SMUMPRD  SMUNPDRD       SMMPPD   SMMAPRT    SMMPPDUN  SMUNMPRT       SMMPDP  SMDPMPRT    SMMPPDXG    SMMPDPXG  SMDPRTXG   SMCHMRD   SMCHMRT    SMMPPDPR    SMMPHQRD  SMMPHQRT    SMMPLQRD  SMSPLTRT    SME1MPRD    SME2MPRD  SME1MPRT  SME2MPRT     SME1MMB     SME2MMB      SME1TTLB  ...  SMMDFLGTH  SMSMFLGTH   SMFGCMN   SMFGCSD   SMFGCSK   SMFGCKT   SM3PBMN   SM3PBSD   SM3PBMD  SM3PB25P  SM3PB75P  SM3PBSDM  SM3PBGN  SMMDMNCV  SMMDCVSD  SMMDCVCV  SMEXCVMD  SMEXCVMAD  SMMNCV  SMUVCRD  SMUVCRT  SMSHRTRD  SMSHRTRT  SMSMRDHQ  SMSMRTHQ  SMPRERDHQ  SMPRERTHQ  SMSMGNDT  SMPREGNDT  SMRDLNMN  SMRDLNMD  SMRDLNSD  \
# sample_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# GTEX-1117F-0005-SM-HL9SH            NaN       B1      nan                   8.3        Blood                               whole blood  UBERON:0013756         1188.0      NaN    BP-38553  RNA isolation PAXgene Blood RNA (Manual)    5/3/13  LCSET-13764       nan  TruSeq.v1  RNA:Total RNA  RNASEQ   nan  134604994.0  367633937.0  232956008.0   72935.0      76.0  16433925.0  304143172.0  127430078.0       0.0  121989620.0  0.957306  14338894.0  0.117542  107650726.0  0.882458  34479795.0  21164891.0  0.613835  133964.0  0.002204  60791324.0  46709230.0  0.382895  75280390.0  0.512743  61034403.0  60955217.0  0.957928  0.956685  13521527.0  11004004.0  4.638615e+09  ...      184.0    77.0952  0.512989  0.088502  0.106281 -0.386421  0.575052  0.311403  0.609091  0.333333  0.862853  0.394237   1532.0  0.089921  0.313438   1.52756  0.542654   0.524121     NaN      NaN      NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN        NaN       NaN       NaN       NaN
# GTEX-1117F-0011-R10b-SM-GI4VE       NaN   B1, A1      nan                   7.2        Brain              brain - frontal cortex (ba9)  UBERON:0009834         1193.0      NaN    BP-42319      RNA Isolation via QIAGEN Spin Column   8/14/13  LCSET-12010       nan  TruSeq.v1  RNA:Total RNA  RNASEQ   nan   67350184.0   75528103.0    8050459.0  127460.0      76.0   3574302.0   12367264.0   64133806.0       0.0   63658224.0  0.992585  41422920.0  0.650708   22235304.0  0.349292  63632092.0  22229041.0  0.349337  345107.0  0.010884  31709272.0  58772285.0  0.923247   4885939.0  0.161648  31884555.0  31773669.0  0.994314  0.990856   5777999.0   6744152.0  2.423226e+09  ...      227.0    85.9908  0.450918  0.088735  0.431654  0.153212  0.677236  0.284687  0.763397  0.500000  0.919192  0.270647   5525.0  1.600000  1.627710   1.00146  0.317303   0.305361     NaN      NaN      NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN        NaN       NaN       NaN       NaN
# GTEX-1117F-0011-R11b-SM-GIN8R       NaN   B1, A1      nan                   6.0        Brain             brain - cerebellar hemisphere  UBERON:0002037         1193.0      NaN    BP-42319      RNA Isolation via QIAGEN Spin Column   8/14/13  LCSET-12011       nan  TruSeq.v1  RNA:Total RNA  RNASEQ   nan   99021352.0  122532321.0   23266593.0  244376.0      76.0   4879614.0   33578345.0   94917928.0       0.0   93852552.0  0.988776  56702303.0  0.604164   37150249.0  0.395836  93805662.0  37136163.0  0.395884  785576.0  0.016839  46651783.0  82287738.0  0.876777  11564814.0  0.150490  47013269.0  46839283.0  0.990609  0.986943   9104653.0  11045926.0  3.573008e+09  ...      220.0    75.6126  0.464407  0.089805  0.479273  0.203122  0.735883  0.258453  0.833333  0.604651  0.936306  0.187664   7779.0  1.685340  1.768670   1.05286  0.326881   0.314845     NaN      NaN      NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN        NaN       NaN       NaN       NaN
# GTEX-1117F-0011-R2b-SM-GI4VL        NaN   B1, A1      nan                   5.7        Brain                  brain - substantia nigra  UBERON:0002038         1193.0      NaN    BP-42208      RNA Isolation via QIAGEN Spin Column   8/12/13  LCSET-12010       nan  TruSeq.v1  RNA:Total RNA  RNASEQ   nan  102541796.0  126416358.0   23734034.0  140528.0      76.0   5688018.0   35903889.0   97733244.0       0.0   96849538.0  0.990958  38788158.0  0.400499   58061380.0  0.599501  96787962.0  58038184.0  0.599643  400397.0  0.008303  48223870.0  83835584.0  0.865627  13013954.0  0.170015  48514920.0  48334618.0  0.992803  0.989113   9121457.0  11355719.0  3.687134e+09  ...      240.0    85.9908  0.453627  0.073098  0.593553  1.329780  0.642670  0.294297  0.720368  0.428571  0.899329  0.312334   4963.0  1.062430  1.370940   1.09517  0.360427   0.348606     NaN      NaN      NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN        NaN       NaN       NaN       NaN
# GTEX-1117F-0011-R3a-SM-GJ3PJ        NaN   B1, A1      nan                   7.1        Brain  brain - anterior cingulate cortex (ba24)  UBERON:0009835         1193.0      NaN    BP-42208      RNA Isolation via QIAGEN Spin Column   8/12/13  LCSET-12012       nan  TruSeq.v1  RNA:Total RNA  RNASEQ   nan   87919278.0  104564329.0   16487319.0  157732.0      76.0   3586415.0   24566291.0   84837998.0       0.0   84118418.0  0.991518  51897218.0  0.616954   32221200.0  0.383046  84088399.0  32214298.0  0.383100  588467.0  0.014062  41848006.0  75020627.0  0.891845   9097791.0  0.174527  42144901.0  41973517.0  0.993538  0.989498   7711933.0   9146972.0  3.203012e+09  ...      226.0    87.4734  0.468294  0.090214  0.518400  0.177329  0.683389  0.286644  0.777778  0.500000  0.920562  0.256071   6600.0  1.650260  1.681710   1.07164  0.328040   0.325567     NaN      NaN      NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN        NaN       NaN       NaN       NaN
#
#                                subject_id      sex    age  DTHHRDY  dataset  original_sample_id  data_type  expression_unit  species  species_ontology                           tissue_original  tissue_ontology  data_type_original  assay_ontology  age_original  developmental_stage_ontology         original_obs_sample_id  tissue_ontology_confidence
# sample_id
# GTEX-1117F-0005-SM-HL9SH       GTEX-1117F  unknown  60-69      4.0     GTEx                        RNA-seq                     human    NCBITaxon:9606                               Whole Blood   UBERON:0000178                         EFO:0009922         60-69                                     GTEX-1117F-0005-SM-HL9SH                      medium
# GTEX-1117F-0011-R10b-SM-GI4VE  GTEX-1117F  unknown  60-69      4.0     GTEx                        RNA-seq                     human    NCBITaxon:9606              Brain - Frontal Cortex (BA9)   UBERON:0013529                         EFO:0009922         60-69                                GTEX-1117F-0011-R10b-SM-GI4VE                      medium
# GTEX-1117F-0011-R11b-SM-GIN8R  GTEX-1117F  unknown  60-69      4.0     GTEx                        RNA-seq                     human    NCBITaxon:9606             Brain - Cerebellar Hemisphere   UBERON:0002245                         EFO:0009922         60-69                                GTEX-1117F-0011-R11b-SM-GIN8R                      medium
# GTEX-1117F-0011-R2b-SM-GI4VL   GTEX-1117F  unknown  60-69      4.0     GTEx                        RNA-seq                     human    NCBITaxon:9606                  Brain - Substantia nigra   UBERON:0002038                         EFO:0009922         60-69                                 GTEX-1117F-0011-R2b-SM-GI4VL                      medium
# GTEX-1117F-0011-R3a-SM-GJ3PJ   GTEX-1117F  unknown  60-69      4.0     GTEx                        RNA-seq                     human    NCBITaxon:9606  Brain - Anterior cingulate cortex (BA24)   UBERON:0009835                         EFO:0009922         60-69                                 GTEX-1117F-0011-R3a-SM-GJ3PJ                      medium
#
# [5 rows x 136 columns]
#
# Unique values in key .obs columns:
#   'dataset': ['GTEx'] (1 total unique)
#   'tissue': ['whole blood', 'brain - frontal cortex (ba9)', 'brain - cerebellar hemisphere', 'brain - substantia nigra', 'brain - anterior cingulate cortex (ba24)', 'brain - amygdala', 'brain - caudate (basal ganglia)', 'brain - nucleus accumbens (basal ganglia)', 'brain - putamen (basal ganglia)', 'adipose - subcutaneous']... (54 total unique)
#   'sex': ['unknown'] (1 total unique)
#   'data_type': ['RNA-seq'] (1 total unique)
#   'expression_unit': [''] (1 total unique)
#   'tissue_ontology': ['UBERON:0000178', 'UBERON:0013529', 'UBERON:0002245', 'UBERON:0002038', 'UBERON:0009835', 'UBERON:0001876', 'UBERON:0001873', 'UBERON:0001882', 'UBERON:0001874', 'UBERON:0002190']... (53 total unique)
#
# Missing values count in key .obs columns:
# {'tissue_ontology': np.int64(979)}
# ------------------------------
#
# --- Variables (.var) Info (GTEX) ---
# .var shape: (58988, 9)
# .var columns: ['gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'original_gene_id', 'ensembl_id', 'mapping_confidence']
# .var index name: None
# First 5 var_names (index): ['ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460']
#
# .var.head():
#                          gene_id        original_ids gene_name       gene_type chromosome     mapping_source original_gene_id       ensembl_id mapping_confidence
# ENSG00000000003  ENSG00000000003  ENSG00000000003.15    TSPAN6  protein_coding       chrX  reference_mapping  ENSG00000000003  ENSG00000000003               high
# ENSG00000000005  ENSG00000000005   ENSG00000000005.6      TNMD  protein_coding       chrX  reference_mapping  ENSG00000000005  ENSG00000000005               high
# ENSG00000000419  ENSG00000000419  ENSG00000000419.14      DPM1  protein_coding      chr20  reference_mapping  ENSG00000000419  ENSG00000000419               high
# ENSG00000000457  ENSG00000000457  ENSG00000000457.14     SCYL3  protein_coding       chr1  reference_mapping  ENSG00000000457  ENSG00000000457               high
# ENSG00000000460  ENSG00000000460  ENSG00000000460.17  C1orf112  protein_coding       chr1  reference_mapping  ENSG00000000460  ENSG00000000460               high
#
# Unique values in key .var columns:
#   'gene_type': ['protein_coding', 'unitary_pseudogene', 'unprocessed_pseudogene', 'processed_pseudogene', 'transcribed_unprocessed_pseudogene', 'processed_transcript', 'antisense', 'polymorphic_pseudogene', 'lincRNA', 'sense_intronic']... (45 total unique)
#   'chromosome': ['chrX', 'chr20', 'chr1', 'chr6', 'chr3', 'chr7', 'chr12', 'chr11', 'chr4', 'chr17']... (26 total unique)
#   'mapping_source': ['reference_mapping', 'unmapped'] (2 total unique)
#   'mapping_confidence': ['high', 'none'] (2 total unique)
# ------------------------------
#
# --- Unstructured Annotation (.uns) Info (GTEX) ---
# .uns keys: ['dataset_info', 'dataset_version', 'gencode_version', 'gene_mapping_stats', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_sources', 'metadata_validation', 'original_gencode_version', 'original_reference_genome', 'processing_date', 'reference_genome', 'rna_seq_protocol']
#
# .uns['dataset_info']:
# {
#   "data_type": "RNA-seq",
#   "expression_unit": "TPM",
#   "gencode_version": "24",
#   "genes": "58988",
#   "samples": "19616",
#   "source": "GTEx",
#   "subject_count": "946",
#   "tissue_count": "54",
#   "version": "v10"
# }
#
# .uns['gene_mapping_stats']:
# {
#   "mapped_genes": "54754",
#   "mapping_percentage": 92.82226893605478,
#   "mapping_source": "reference_mapping",
#   "total_genes": "58988"
# }
#
# .uns['metadata_validation']:
# {
#   "dataset": "GTEx",
#   "missing_fields": "[]",
#   "missing_values": {
#     "DTHHRDY": "113",
#     "SMATSSCR": "4536",
#     "SMGEBTCHD": "2981",
#     "SMGTC": "19616",
#     "SMMNCV": "19616",
#     "SMPREGNDT": "19616",
#     "SMPRERDHQ": "19616",
#     "SMPRERTHQ": "19616",
#     "SMPTHNTS": "4537",
#     "SMRDLNMD": "19616",
#     "SMRDLNMN": "19616",
#     "SMRDLNSD": "19616",
#     "SMSHRTRD": "19616",
#     "SMSHRTRT": "19616",
#     "SMSMGNDT": "19616",
#     "SMSMRDHQ": "19616",
#     "SMSMRTHQ": "19616",
#     "SMTSPAX": "4557",
#     "SMUVCRD": "19616",
#     "SMUVCRT": "19616",
#     "batch": "11",
#     "ischemic_time": "24"
#   },
#   "sample_count": "19616",
#   "unmapped_ages": "['60-69' '50-59' '40-49' '20-29' '30-39' '70-79']",
#   "unmapped_assays": "[]",
#   "unmapped_tissues": "[]",
#   "validation_status": "warning"
# }
#
# .uns['harmonized_gencode_version']:
# 24
#
# .uns['harmonized_reference_genome']:
# hg38
# ------------------------------
#
#
# ========================= Inspecting: MAGE =========================
#
# --- AnnData Object Info (MAGE) ---
# AnnData object with n_obs × n_vars = 731 × 19428
#     obs: 'sample_id', 'donor_id', 'subject_id', 'tissue', 'dataset', 'data_type', 'expression_unit', 'is_gencode', 'is_ensembl', 'sex', 'age', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence'
#     var: 'gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'original_gene_id', 'ensembl_id', 'mapping_confidence'
#     uns: 'assay_ontology', 'cell_type_info', 'data_type', 'dataset_info', 'gencode_version', 'gene_mapping_stats', 'genome_info', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_sources', 'metadata_validation', 'ontology_mappings', 'platform', 'processing_date', 'reference_genome', 'rna_seq_protocol'
# ------------------------------
#
# --- Observations (.obs) Info (MAGE) ---
# .obs shape: (731, 20)
# .obs columns: ['sample_id', 'donor_id', 'subject_id', 'tissue', 'dataset', 'data_type', 'expression_unit', 'is_gencode', 'is_ensembl', 'sex', 'age', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence']
#
# .obs.head():
#                        sample_id donor_id subject_id       tissue dataset data_type expression_unit is_gencode is_ensembl      sex age species species_ontology tissue_original tissue_ontology data_type_original assay_ontology age_original developmental_stage_ontology tissue_ontology_confidence
# _sample_id
# NA06985_NA06985  NA06985_NA06985  NA06985    NA06985  lymphoblast    MAGE   rna-seq             TPM      False       True  unknown       human   NCBITaxon:9606     lymphoblast                            RNA-seq    EFO:0009922                                                                 none
# NA07000_NA07000  NA07000_NA07000  NA07000    NA07000  lymphoblast    MAGE   rna-seq             TPM      False       True  unknown       human   NCBITaxon:9606     lymphoblast                            RNA-seq    EFO:0009922                                                                 none
# NA11919_NA11919  NA11919_NA11919  NA11919    NA11919  lymphoblast    MAGE   rna-seq             TPM      False       True  unknown       human   NCBITaxon:9606     lymphoblast                            RNA-seq    EFO:0009922                                                                 none
# NA11930_NA11930  NA11930_NA11930  NA11930    NA11930  lymphoblast    MAGE   rna-seq             TPM      False       True  unknown       human   NCBITaxon:9606     lymphoblast                            RNA-seq    EFO:0009922                                                                 none
# NA11932_NA11932  NA11932_NA11932  NA11932    NA11932  lymphoblast    MAGE   rna-seq             TPM      False       True  unknown       human   NCBITaxon:9606     lymphoblast                            RNA-seq    EFO:0009922                                                                 none
#
# Unique values in key .obs columns:
#   'dataset': ['MAGE'] (1 total unique)
#   'tissue': ['lymphoblast'] (1 total unique)
#   'sex': ['unknown'] (1 total unique)
#   'data_type': ['rna-seq'] (1 total unique)
#   'expression_unit': ['TPM'] (1 total unique)
#   'tissue_ontology': [''] (1 total unique)
#
# Missing values count in key .obs columns:
# {'age': np.int64(731), 'tissue_ontology': np.int64(731)}
# ------------------------------
#
# --- Variables (.var) Info (MAGE) ---
# .var shape: (19428, 9)
# .var columns: ['gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'original_gene_id', 'ensembl_id', 'mapping_confidence']
# .var index name: None
# First 5 var_names (index): ['ENSG00000000003', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938']
#
# .var.head():
#                          gene_id        original_ids gene_name       gene_type chromosome     mapping_source original_gene_id       ensembl_id mapping_confidence
# ENSG00000000003  ENSG00000000003  ENSG00000000003.14    TSPAN6  protein_coding       chrX  reference_mapping  ENSG00000000003  ENSG00000000003               high
# ENSG00000000419  ENSG00000000419  ENSG00000000419.12      DPM1  protein_coding      chr20  reference_mapping  ENSG00000000419  ENSG00000000419               high
# ENSG00000000457  ENSG00000000457  ENSG00000000457.13     SCYL3  protein_coding       chr1  reference_mapping  ENSG00000000457  ENSG00000000457               high
# ENSG00000000460  ENSG00000000460  ENSG00000000460.16  C1orf112  protein_coding       chr1  reference_mapping  ENSG00000000460  ENSG00000000460               high
# ENSG00000000938  ENSG00000000938  ENSG00000000938.12       FGR  protein_coding       chr1  reference_mapping  ENSG00000000938  ENSG00000000938               high
#
# Unique values in key .var columns:
#   'gene_type': ['protein_coding', 'transcribed_unprocessed_pseudogene', 'unprocessed_pseudogene', 'unitary_pseudogene', 'processed_transcript', 'lincRNA', 'processed_pseudogene', 'sense_intronic', 'antisense', 'transcribed_processed_pseudogene']... (32 total unique)
#   'chromosome': ['chrX', 'chr20', 'chr1', 'chr6', 'chr3', 'chr7', 'chr12', 'chr11', 'chr4', 'chr17']... (23 total unique)
#   'mapping_source': ['reference_mapping'] (1 total unique)
#   'mapping_confidence': ['high'] (1 total unique)
# ------------------------------
#
# --- Unstructured Annotation (.uns) Info (MAGE) ---
# .uns keys: ['assay_ontology', 'cell_type_info', 'data_type', 'dataset_info', 'gencode_version', 'gene_mapping_stats', 'genome_info', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_sources', 'metadata_validation', 'ontology_mappings', 'platform', 'processing_date', 'reference_genome', 'rna_seq_protocol']
#
# .uns['dataset_info']:
# {
#   "accession": "PRJNA851328",
#   "cell_type": "lymphoblastoid cell lines",
#   "continental_groups": "5",
#   "data_repository": "[{\"name\": \"Sequence Read Archive (SRA)\", \"accession\": \"PRJNA851328\"}, {\"name\": \"Zenodo\", \"doi\": \"10.5281/zenodo.10535719\"}]",
#   "library_count": "779",
#   "populations": "26",
#   "sample_size": "731"
# }
#
# .uns['gene_mapping_stats']:
# {
#   "mapped_genes": "19428",
#   "mapping_percentage": 100.0,
#   "mapping_source": "reference_mapping",
#   "total_genes": "19428"
# }
#
# .uns['metadata_validation']:
# {
#   "dataset": "MAGE",
#   "missing_fields": "[]",
#   "missing_values": {},
#   "sample_count": "731",
#   "unmapped_ages": "[]",
#   "unmapped_assays": "[]",
#   "unmapped_tissues": "[]",
#   "validation_status": "warning"
# }
#
# .uns['harmonized_gencode_version']:
# 24
#
# .uns['harmonized_reference_genome']:
# hg38
# ------------------------------
#
# ========================= Inspection Complete =========================
