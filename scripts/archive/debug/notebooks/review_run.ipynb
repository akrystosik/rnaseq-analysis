# %%
# Cell 1: Setup - Imports and Paths
import scanpy as sc
import pandas as pd
import numpy as np
import os
import warnings
import sys

# Ignore specific warnings often encountered with AnnData
warnings.filterwarnings("ignore", category=FutureWarning, module="anndata")
# Allow viewing more columns
pd.set_option('display.max_columns', 50)

# --- Define paths for the LATEST run ---
RUN_ID = "run_20250501_045924" # From the log file name
BASE_DIR = "/mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq"
STAGE_1_2_DIR = os.path.join(BASE_DIR, "standardized_data", RUN_ID)
STAGE_2_5_DIR = os.path.join(BASE_DIR, "preprocessed_data", RUN_ID)
COMBINED_FILE = os.path.join(STAGE_1_2_DIR, "combined_all_genes_sparse_standardized.h5ad")

print(f"Run ID: {RUN_ID}")
print(f"Stage 1&2 Output Directory: {STAGE_1_2_DIR}")
print(f"Stage 2.5 Output Directory: {STAGE_2_5_DIR}")
print(f"Combined File Path: {COMBINED_FILE}")

# Function to safely load h5ad
def load_h5ad_safe(filepath):
    print(f"\n--- Loading: {filepath} ---")
    if not os.path.exists(filepath):
        print(f"ERROR: File not found!")
        return None
    try:
        adata = sc.read_h5ad(filepath)
        print(f"Successfully loaded. Shape: {adata.shape}")
        return adata
    except Exception as e:
        print(f"ERROR loading file: {e}")
        return None

# Function to inspect adata
def inspect_adata(adata, name="Dataset"):
    if adata is None:
        return
    print(f"\n--- Inspecting {name} ---")
    print("Shape:", adata.shape)

    print("\nOBS (head):")
    try:
        display(adata.obs.head())
    except NameError: # If not in notebook
        print(adata.obs.head().to_string())
    print("\nOBS Columns:", list(adata.obs.columns))
    print("\nOBS Dtypes:\n", adata.obs.dtypes.value_counts())

    print("\nVAR (head):")
    try:
        display(adata.var.head())
    except NameError:
        print(adata.var.head().to_string())
    print("\nVAR Columns:", list(adata.var.columns))
    print("\nVAR Dtypes:\n", adata.var.dtypes.value_counts())


    print("\nUNS Keys:", list(adata.uns.keys()))
    # Look for specific problematic keys from logs
    problem_keys = ['metadata_sources', 'dataset_info']
    for key in problem_keys:
        if key in adata.uns:
             print(f"  UNS['{key}'] type: {type(adata.uns[key])}")
             # Print snippet if it's a dict or list
             if isinstance(adata.uns[key], (dict, list)):
                  print(f"  UNS['{key}'] (snippet): {str(adata.uns[key])[:200]}...")

    # Check specific obs columns known to cause issues
    problem_obs_cols = ['cell_type_info']
    for col in problem_obs_cols:
         if col in adata.obs.columns:
              print(f"  OBS Column '{col}' dtype: {adata.obs[col].dtype}")
              print(f"  OBS Column '{col}' (sample values): {adata.obs[col].unique()[:5]}")
# Out:
# Run ID: run_20250501_045924
# Stage 1&2 Output Directory: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/standardized_data/run_20250501_045924
# Stage 2.5 Output Directory: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250501_045924
# Combined File Path: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/standardized_data/run_20250501_045924/combined_all_genes_sparse_standardized.h5ad

# %%
# Cell 2: Inspect Stage 1 Output (V1 files - before Stage 2 processing)
# Note: We expect ENCODE, GTEx, MAGE v1 files might be corrupted due to save errors.
# ADNI v1 should be okay.

adata_adni_v1 = load_h5ad_safe(os.path.join(STAGE_1_2_DIR, "adni_standardized_v1.h5ad"))
inspect_adata(adata_adni_v1, "ADNI_v1 (Stage 1 Output)")

adata_encode_v1 = load_h5ad_safe(os.path.join(STAGE_1_2_DIR, "encode_standardized_v1.h5ad"))
# inspect_adata(adata_encode_v1, "ENCODE_v1 (Stage 1 Output)") # This might fail or show incomplete data

adata_gtex_v1 = load_h5ad_safe(os.path.join(STAGE_1_2_DIR, "gtex_standardized_v1.h5ad"))
# inspect_adata(adata_gtex_v1, "GTEx_v1 (Stage 1 Output)") # This might fail or show incomplete data

adata_mage_v1 = load_h5ad_safe(os.path.join(STAGE_1_2_DIR, "mage_standardized_v1.h5ad"))
# inspect_adata(adata_mage_v1, "MAGE_v1 (Stage 1 Output)") # This might fail or show incomplete data

# You might need to uncomment the inspect_adata calls one by one if they fail due to corruption.
# Focus on whether the file loads at all, and if so, what .obs/.uns looks like.
# Out:
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/standardized_data/run_20250501_045924/adni_standardized_v1.h5ad ---
# Successfully loaded. Shape: (650, 17991)
#
# --- Inspecting ADNI_v1 (Stage 1 Output) ---
# Shape: (650, 17991)
#
# OBS (head):
#                                                                          sample_id  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268_002_S_1268_gencode_v24_pruned
#
#                                           subject_id dataset   data_type  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413    ADNI  Microarray
# 002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729    ADNI  Microarray
# 002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155    ADNI  Microarray
# 002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261    ADNI  Microarray
# 002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268    ADNI  Microarray
#
#                                                expression_unit tissue  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  Normalized intensity  blood
# 002_S_0729_002_S_0729_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1155_002_S_1155_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1261_002_S_1261_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1268_002_S_1268_gencode_v24_pruned  Normalized intensity  blood
#
#                                                                     platform  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_0729_002_S_0729_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_1155_002_S_1155_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_1261_002_S_1261_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_1268_002_S_1268_gencode_v24_pruned  Affymetrix Human Genome U219 Array
#
#                                            processing      sex age species  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_0729_002_S_0729_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_1155_002_S_1155_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_1261_002_S_1261_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_1268_002_S_1268_gencode_v24_pruned  gencode_v24  unknown       human
#
#                                          species_ontology tissue_original  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_0729_002_S_0729_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_1155_002_S_1155_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_1261_002_S_1261_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_1268_002_S_1268_gencode_v24_pruned   NCBITaxon:9606           blood
#
#                                          tissue_ontology data_type_original  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_0729_002_S_0729_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_1155_002_S_1155_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_1261_002_S_1261_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_1268_002_S_1268_gencode_v24_pruned  UBERON:0000178         Microarray
#
#                                          assay_ontology age_original  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned
#
#                                          developmental_stage_ontology
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned
# OBS Columns: ['sample_id', 'subject_id', 'dataset', 'data_type', 'expression_unit', 'tissue', 'platform', 'processing', 'sex', 'age', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology']
#
# OBS Dtypes:
#  category    4
# object      2
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# VAR (head):
#                          gene_id        original_ids gene_name  \
# ENSG00000000003  ENSG00000000003  ENSG00000000003.14    TSPAN6
# ENSG00000000005  ENSG00000000005   ENSG00000000005.5      TNMD
# ENSG00000000419  ENSG00000000419  ENSG00000000419.12      DPM1
# ENSG00000000457  ENSG00000000457  ENSG00000000457.13     SCYL3
# ENSG00000000938  ENSG00000000938  ENSG00000000938.12       FGR
#
#                       gene_type chromosome mapping_source
# ENSG00000000003  protein_coding       chrX    exact_match
# ENSG00000000005  protein_coding       chrX    exact_match
# ENSG00000000419  protein_coding      chr20    exact_match
# ENSG00000000457  protein_coding       chr1    exact_match
# ENSG00000000938  protein_coding       chr1    exact_match
# VAR Columns: ['gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source']
#
# VAR Dtypes:
#  object      2
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# UNS Keys: ['dataset_info', 'gencode_version', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_validation', 'ontology_mappings', 'original_gencode_version', 'original_reference_genome', 'processing_date', 'reference_genome', 'subject_demographics']
#   UNS['dataset_info'] type: <class 'dict'>
#   UNS['dataset_info'] (snippet): {'assay_ontology': 'EFO:0002695', 'data_type': 'microarray', 'description': "Alzheimer's Disease Neuroimaging Initiative microarray data with demographic information", 'expression_unit': 'quantile nor...
#
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/standardized_data/run_20250501_045924/encode_standardized_v1.h5ad ---
# Successfully loaded. Shape: (7, 65586)
#
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/standardized_data/run_20250501_045924/gtex_standardized_v1.h5ad ---
# Successfully loaded. Shape: (19616, 58988)
#
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/standardized_data/run_20250501_045924/mage_standardized_v1.h5ad ---
# Successfully loaded. Shape: (731, 19428)

# %%
# Cell 3: Inspect Stage 2 Output (V2 files)
# Note: We expect ENCODE, GTEx, MAGE v2 files might *not exist* or be corrupted
# because the save failed in standardize_metadata.py. ADNI v2 should exist.

adata_adni_v2 = load_h5ad_safe(os.path.join(STAGE_1_2_DIR, "adni_standardized_v2.h5ad"))
inspect_adata(adata_adni_v2, "ADNI_v2 (Stage 2 Output)")

# Check existence of others (likely False)
print("\nChecking for V2 files potentially missing due to save errors:")
print(f"Encode V2 exists: {os.path.exists(os.path.join(STAGE_1_2_DIR, 'encode_standardized_v2.h5ad'))}")
print(f"GTEx V2 exists:   {os.path.exists(os.path.join(STAGE_1_2_DIR, 'gtex_standardized_v2.h5ad'))}")
print(f"MAGE V2 exists:   {os.path.exists(os.path.join(STAGE_1_2_DIR, 'mage_standardized_v2.h5ad'))}")
# Out:
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/standardized_data/run_20250501_045924/adni_standardized_v2.h5ad ---
# Successfully loaded. Shape: (650, 17991)
#
# --- Inspecting ADNI_v2 (Stage 2 Output) ---
# Shape: (650, 17991)
#
# OBS (head):
#                                                                          sample_id  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268_002_S_1268_gencode_v24_pruned
#
#                                           subject_id dataset   data_type  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413    ADNI  Microarray
# 002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729    ADNI  Microarray
# 002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155    ADNI  Microarray
# 002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261    ADNI  Microarray
# 002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268    ADNI  Microarray
#
#                                                expression_unit tissue  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  Normalized intensity  blood
# 002_S_0729_002_S_0729_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1155_002_S_1155_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1261_002_S_1261_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1268_002_S_1268_gencode_v24_pruned  Normalized intensity  blood
#
#                                                                     platform  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_0729_002_S_0729_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_1155_002_S_1155_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_1261_002_S_1261_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_1268_002_S_1268_gencode_v24_pruned  Affymetrix Human Genome U219 Array
#
#                                            processing      sex age species  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_0729_002_S_0729_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_1155_002_S_1155_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_1261_002_S_1261_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_1268_002_S_1268_gencode_v24_pruned  gencode_v24  unknown       human
#
#                                          species_ontology tissue_original  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_0729_002_S_0729_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_1155_002_S_1155_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_1261_002_S_1261_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_1268_002_S_1268_gencode_v24_pruned   NCBITaxon:9606           blood
#
#                                          tissue_ontology data_type_original  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_0729_002_S_0729_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_1155_002_S_1155_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_1261_002_S_1261_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_1268_002_S_1268_gencode_v24_pruned  UBERON:0000178         Microarray
#
#                                          assay_ontology age_original  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned
#
#                                          developmental_stage_ontology  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned
#
#                                          tissue_ontology_confidence
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned                     medium
# 002_S_0729_002_S_0729_gencode_v24_pruned                     medium
# 002_S_1155_002_S_1155_gencode_v24_pruned                     medium
# 002_S_1261_002_S_1261_gencode_v24_pruned                     medium
# 002_S_1268_002_S_1268_gencode_v24_pruned                     medium
# OBS Columns: ['sample_id', 'subject_id', 'dataset', 'data_type', 'expression_unit', 'tissue', 'platform', 'processing', 'sex', 'age', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence']
#
# OBS Dtypes:
#  category    4
# object      2
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# VAR (head):
#                          gene_id        original_ids gene_name  \
# ENSG00000000003  ENSG00000000003  ENSG00000000003.14    TSPAN6
# ENSG00000000005  ENSG00000000005   ENSG00000000005.5      TNMD
# ENSG00000000419  ENSG00000000419  ENSG00000000419.12      DPM1
# ENSG00000000457  ENSG00000000457  ENSG00000000457.13     SCYL3
# ENSG00000000938  ENSG00000000938  ENSG00000000938.12       FGR
#
#                       gene_type chromosome mapping_source
# ENSG00000000003  protein_coding       chrX    exact_match
# ENSG00000000005  protein_coding       chrX    exact_match
# ENSG00000000419  protein_coding      chr20    exact_match
# ENSG00000000457  protein_coding       chr1    exact_match
# ENSG00000000938  protein_coding       chr1    exact_match
# VAR Columns: ['gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source']
#
# VAR Dtypes:
#  object      2
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# UNS Keys: ['dataset_info', 'gencode_version', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_validation', 'ontology_mappings', 'original_gencode_version', 'original_reference_genome', 'processing_date', 'reference_genome', 'subject_demographics']
#   UNS['dataset_info'] type: <class 'dict'>
#   UNS['dataset_info'] (snippet): {'assay_ontology': 'EFO:0002695', 'data_type': 'microarray', 'description': "Alzheimer's Disease Neuroimaging Initiative microarray data with demographic information", 'expression_unit': 'quantile nor...
#
# Checking for V2 files potentially missing due to save errors:
# Encode V2 exists: True
# GTEx V2 exists:   True
# MAGE V2 exists:   True

# %%
# Cell 4: Inspect Stage 2.5 Output (Preprocessed files)
# These should exist and reflect the state before combining.

adata_adni_prep = load_h5ad_safe(os.path.join(STAGE_2_5_DIR, "adni_standardized_preprocessed.h5ad"))
inspect_adata(adata_adni_prep, "ADNI Preprocessed (Stage 2.5 Output)")

adata_encode_prep = load_h5ad_safe(os.path.join(STAGE_2_5_DIR, "encode_standardized_preprocessed.h5ad"))
inspect_adata(adata_encode_prep, "ENCODE Preprocessed (Stage 2.5 Output)")
# Check if placeholders were fixed in the *next* step (should still be present here)
if adata_encode_prep and 'gene_id' in adata_encode_prep.var.columns:
    placeholders = adata_encode_prep.var[adata_encode_prep.var['gene_id'].astype(str).str.startswith('PLACEHOLDER_')]
    print(f"\nPlaceholders found in ENCODE preprocessed var['gene_id']: {len(placeholders)}")

adata_gtex_prep = load_h5ad_safe(os.path.join(STAGE_2_5_DIR, "gtex_standardized_preprocessed.h5ad"))
inspect_adata(adata_gtex_prep, "GTEx Preprocessed (Stage 2.5 Output)")

adata_mage_prep = load_h5ad_safe(os.path.join(STAGE_2_5_DIR, "mage_standardized_preprocessed.h5ad"))
inspect_adata(adata_mage_prep, "MAGE Preprocessed (Stage 2.5 Output)")
# Out:
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250501_045924/adni_standardized_preprocessed.h5ad ---
# Successfully loaded. Shape: (650, 17991)
#
# --- Inspecting ADNI Preprocessed (Stage 2.5 Output) ---
# Shape: (650, 17991)
#
# OBS (head):
#                                                                          sample_id  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268_002_S_1268_gencode_v24_pruned
#
#                                           subject_id dataset   data_type  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413    ADNI  Microarray
# 002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729    ADNI  Microarray
# 002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155    ADNI  Microarray
# 002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261    ADNI  Microarray
# 002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268    ADNI  Microarray
#
#                                                expression_unit tissue  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  Normalized intensity  blood
# 002_S_0729_002_S_0729_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1155_002_S_1155_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1261_002_S_1261_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1268_002_S_1268_gencode_v24_pruned  Normalized intensity  blood
#
#                                                                     platform  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_0729_002_S_0729_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_1155_002_S_1155_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_1261_002_S_1261_gencode_v24_pruned  Affymetrix Human Genome U219 Array
# 002_S_1268_002_S_1268_gencode_v24_pruned  Affymetrix Human Genome U219 Array
#
#                                            processing      sex age species  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_0729_002_S_0729_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_1155_002_S_1155_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_1261_002_S_1261_gencode_v24_pruned  gencode_v24  unknown       human
# 002_S_1268_002_S_1268_gencode_v24_pruned  gencode_v24  unknown       human
#
#                                          species_ontology tissue_original  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_0729_002_S_0729_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_1155_002_S_1155_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_1261_002_S_1261_gencode_v24_pruned   NCBITaxon:9606           blood
# 002_S_1268_002_S_1268_gencode_v24_pruned   NCBITaxon:9606           blood
#
#                                          tissue_ontology data_type_original  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_0729_002_S_0729_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_1155_002_S_1155_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_1261_002_S_1261_gencode_v24_pruned  UBERON:0000178         Microarray
# 002_S_1268_002_S_1268_gencode_v24_pruned  UBERON:0000178         Microarray
#
#                                          assay_ontology age_original  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned
#
#                                          developmental_stage_ontology  \
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned
#
#                                          tissue_ontology_confidence
# _sample_id
# 002_S_0413_002_S_0413_gencode_v24_pruned                     medium
# 002_S_0729_002_S_0729_gencode_v24_pruned                     medium
# 002_S_1155_002_S_1155_gencode_v24_pruned                     medium
# 002_S_1261_002_S_1261_gencode_v24_pruned                     medium
# 002_S_1268_002_S_1268_gencode_v24_pruned                     medium
# OBS Columns: ['sample_id', 'subject_id', 'dataset', 'data_type', 'expression_unit', 'tissue', 'platform', 'processing', 'sex', 'age', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence']
#
# OBS Dtypes:
#  category    4
# object      2
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# VAR (head):
#                          gene_id        original_ids gene_name  \
# ENSG00000000003  ENSG00000000003  ENSG00000000003.14    TSPAN6
# ENSG00000000005  ENSG00000000005   ENSG00000000005.5      TNMD
# ENSG00000000419  ENSG00000000419  ENSG00000000419.12      DPM1
# ENSG00000000457  ENSG00000000457  ENSG00000000457.13     SCYL3
# ENSG00000000938  ENSG00000000938  ENSG00000000938.12       FGR
#
#                       gene_type chromosome     mapping_source  \
# ENSG00000000003  protein_coding       chrX  reference_mapping
# ENSG00000000005  protein_coding       chrX  reference_mapping
# ENSG00000000419  protein_coding      chr20  reference_mapping
# ENSG00000000457  protein_coding       chr1  reference_mapping
# ENSG00000000938  protein_coding       chr1  reference_mapping
#
#                 original_gene_id       ensembl_id mapping_confidence
# ENSG00000000003  ENSG00000000003  ENSG00000000003               high
# ENSG00000000005  ENSG00000000005  ENSG00000000005               high
# ENSG00000000419  ENSG00000000419  ENSG00000000419               high
# ENSG00000000457  ENSG00000000457  ENSG00000000457               high
# ENSG00000000938  ENSG00000000938  ENSG00000000938               high
# VAR Columns: ['gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'original_gene_id', 'ensembl_id', 'mapping_confidence']
#
# VAR Dtypes:
#  object      4
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# UNS Keys: ['dataset_info', 'gencode_version', 'gene_mapping_stats', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_validation', 'ontology_mappings', 'original_gencode_version', 'original_reference_genome', 'processing_date', 'reference_genome', 'subject_demographics']
#   UNS['dataset_info'] type: <class 'dict'>
#   UNS['dataset_info'] (snippet): {'assay_ontology': 'EFO:0002695', 'data_type': 'microarray', 'description': "Alzheimer's Disease Neuroimaging Initiative microarray data with demographic information", 'expression_unit': 'quantile nor...
#
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250501_045924/encode_standardized_preprocessed.h5ad ---
# Successfully loaded. Shape: (7, 65586)
#
# --- Inspecting ENCODE Preprocessed (Stage 2.5 Output) ---
# Shape: (7, 65586)
#
# OBS (head):
#     _sample_id age cell_line    cell_type cell_type_info depletion  \
# 0  ENCFF244DNJ  58      A549   epithelial                     rRNA
# 1  ENCFF685WJV  69     Caki2   epithelial                     rRNA
# 2  ENCFF640FPG  53   GM23248   Fibroblast                     rRNA
# 3  ENCFF863QWG  15     HepG2   epithelial                     rRNA
# 4  ENCFF171FQU  53      K562  lymphoblast                     rRNA
#
#                                       description  \
# 0                  Human lung carcinoma cell line
# 1     Human kidney clear cell carcinoma cell line
# 2                 Human skin fibroblast cell line
# 3  Human liver hepatocellular carcinoma cell line
# 4    Human chronic myelogenous leukemia cell line
#
#                            disease ethnicity        geo_id  \
# 0                   adenocarcinoma  European  SAMN05733878
# 1  clear cell renal cell carcinoma  European  SAMN04284635
# 2                           normal  European  SAMN04284514
# 3         hepatocellular carcinoma  European  SAMN04284581
# 4     chronic myelogenous leukemia   unknown  SAMN04284550
#
#      nucleic_acid_type organism original_sample_id     sex size_range  \
# 0  polyadenylated mRNA    human        ENCFF244DNJ    male       >200
# 1                  RNA    human        ENCFF685WJV    male       >200
# 2                  RNA    human        ENCFF640FPG    male       >200
# 3                  RNA    human        ENCFF863QWG    male       >200
# 4                  RNA    human        ENCFF171FQU  female       >200
#
#           strand_specificity   subject_id       tissue data_type  \
# 0  Strand-specific (reverse)  ENCDO451RUA         lung   RNA-seq
# 1  Strand-specific (reverse)  ENCDO869AAI       kidney   RNA-seq
# 2  Strand-specific (reverse)  ENCDO467QPX         skin   RNA-seq
# 3  Strand-specific (reverse)  ENCDO886MPB        liver   RNA-seq
# 4  Strand-specific (reverse)  ENCDO000AAL  bone marrow   RNA-seq
#
#   assay_ontology species species_ontology dataset sample_id tissue_ontology  \
# 0    EFO:0009922   human   NCBITaxon:9606  encode         0  UBERON:0002048
# 1    EFO:0009922   human   NCBITaxon:9606  encode         1  UBERON:0002113
# 2    EFO:0009922   human   NCBITaxon:9606  encode         2  UBERON:0002097
# 3    EFO:0009922   human   NCBITaxon:9606  encode         3  UBERON:0002107
# 4    EFO:0009922   human   NCBITaxon:9606  encode         4  UBERON:0002371
#
#   developmental_stage_ontology expression_unit tissue_ontology_confidence
# 0                                      unknown                     medium
# 1                                      unknown                     medium
# 2                                      unknown                     medium
# 3                                      unknown                     medium
# 4                                      unknown                     medium
# OBS Columns: ['_sample_id', 'age', 'cell_line', 'cell_type', 'cell_type_info', 'depletion', 'description', 'disease', 'ethnicity', 'geo_id', 'nucleic_acid_type', 'organism', 'original_sample_id', 'sex', 'size_range', 'strand_specificity', 'subject_id', 'tissue', 'data_type', 'assay_ontology', 'species', 'species_ontology', 'dataset', 'sample_id', 'tissue_ontology', 'developmental_stage_ontology', 'expression_unit', 'tissue_ontology_confidence']
#
# OBS Dtypes:
#  object      7
# category    2
# category    2
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# VAR (head):
#            gene_id                                   original_gene_id  \
# 0  ENSG00000169045  ENST00000518548.5|ENSG00000169045.17|OTTHUMG00...
# 1  ENSG00000278290                                  ENSG00000278290.1
# 2  ENSG00000172428                                 ENSG00000172428.10
# 3  ENSG00000231924  ENST00000595124.5|ENSG00000231924.9|OTTHUMG000...
# 4  ENSG00000226137                                  ENSG00000226137.3
#
#         ensembl_id   gene_name       gene_type chromosome  mapping_source  \
# 0  ENSG00000169045     HNRNPH1  protein_coding       chr5  encode_mapping
# 1  ENSG00000278290  AC099050.1           miRNA       chr3  encode_mapping
# 2  ENSG00000172428      MYEOV2  protein_coding       chr2  encode_mapping
# 3  ENSG00000231924        PSG1  protein_coding      chr19  encode_mapping
# 4  ENSG00000226137  BAIAP2-AS1         lincRNA      chr17  encode_mapping
#
#   mapping_confidence
# 0               high
# 1               high
# 2               high
# 3               high
# 4               high
# VAR Columns: ['gene_id', 'original_gene_id', 'ensembl_id', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'mapping_confidence']
#
# VAR Dtypes:
#  category    2
# object      1
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# UNS Keys: ['assay_ontology', 'data_type', 'dataset_info', 'gencode_version', 'gene_mapping_stats', 'genome_info', 'harmonized_gencode_version', 'harmonized_reference_genome', 'platform', 'reference_genome', 'rna_seq_protocol']
#   UNS['dataset_info'] type: <class 'dict'>
#   UNS['dataset_info'] (snippet): {'cell_lines': {'A549': {'age': '58', 'cell_type': 'epithelial', 'cell_type_info': {'anatomical_entity_id': 'UBERON:0002048', 'cell_type_id': 'CL:0000066'}, 'depletion': 'rRNA', 'description': 'Human ...
#   OBS Column 'cell_type_info' dtype: category
#   OBS Column 'cell_type_info' (sample values): ['']
# Categories (1, object): ['']
#
# Placeholders found in ENCODE preprocessed var['gene_id']: 0
#
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250501_045924/gtex_standardized_preprocessed.h5ad ---
# Successfully loaded. Shape: (19616, 58988)
#
# --- Inspecting GTEx Preprocessed (Stage 2.5 Output) ---
# Shape: (19616, 58988)
#
# OBS (head):
#                               SMATSSCR SMCENTER SMPTHNTS rna_integrity_number  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH           nan       B1                           8.3
# GTEX-1117F-0011-R10b-SM-GI4VE      nan   B1, A1                           7.2
# GTEX-1117F-0011-R11b-SM-GIN8R      nan   B1, A1                           6.0
# GTEX-1117F-0011-R2b-SM-GI4VL       nan   B1, A1                           5.7
# GTEX-1117F-0011-R3a-SM-GJ3PJ       nan   B1, A1                           7.1
#
#                               broad_tissue  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH             Blood
# GTEX-1117F-0011-R10b-SM-GI4VE        Brain
# GTEX-1117F-0011-R11b-SM-GIN8R        Brain
# GTEX-1117F-0011-R2b-SM-GI4VL         Brain
# GTEX-1117F-0011-R3a-SM-GJ3PJ         Brain
#
#                                                                  tissue  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH                                    whole blood
# GTEX-1117F-0011-R10b-SM-GI4VE              brain - frontal cortex (ba9)
# GTEX-1117F-0011-R11b-SM-GIN8R             brain - cerebellar hemisphere
# GTEX-1117F-0011-R2b-SM-GI4VL                   brain - substantia nigra
# GTEX-1117F-0011-R3a-SM-GJ3PJ   brain - anterior cingulate cortex (ba24)
#
#                                       SMUBRID ischemic_time SMTSPAX  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH       UBERON:0013756        1188.0     nan
# GTEX-1117F-0011-R10b-SM-GI4VE  UBERON:0009834        1193.0     nan
# GTEX-1117F-0011-R11b-SM-GIN8R  UBERON:0002037        1193.0     nan
# GTEX-1117F-0011-R2b-SM-GI4VL   UBERON:0002038        1193.0     nan
# GTEX-1117F-0011-R3a-SM-GJ3PJ   UBERON:0009835        1193.0     nan
#
#                               array_batch  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH         BP-38553
# GTEX-1117F-0011-R10b-SM-GI4VE    BP-42319
# GTEX-1117F-0011-R11b-SM-GIN8R    BP-42319
# GTEX-1117F-0011-R2b-SM-GI4VL     BP-42208
# GTEX-1117F-0011-R3a-SM-GJ3PJ     BP-42208
#
#                                                               SMNABTCHT  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH       RNA isolation PAXgene Blood RNA (Manual)
# GTEX-1117F-0011-R10b-SM-GI4VE      RNA Isolation via QIAGEN Spin Column
# GTEX-1117F-0011-R11b-SM-GIN8R      RNA Isolation via QIAGEN Spin Column
# GTEX-1117F-0011-R2b-SM-GI4VL       RNA Isolation via QIAGEN Spin Column
# GTEX-1117F-0011-R3a-SM-GJ3PJ       RNA Isolation via QIAGEN Spin Column
#
#                               SMNABTCHD        batch SMGEBTCHD  SMGEBTCHT  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH         5/3/13  LCSET-13764            TruSeq.v1
# GTEX-1117F-0011-R10b-SM-GI4VE   8/14/13  LCSET-12010            TruSeq.v1
# GTEX-1117F-0011-R11b-SM-GIN8R   8/14/13  LCSET-12011            TruSeq.v1
# GTEX-1117F-0011-R2b-SM-GI4VL    8/12/13  LCSET-12010            TruSeq.v1
# GTEX-1117F-0011-R3a-SM-GJ3PJ    8/12/13  LCSET-12012            TruSeq.v1
#
#                                 ANALYTE_TYPE SMAFRZE SMGTC      SMRDTTL  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH       RNA:Total RNA  RNASEQ        134604994.0
# GTEX-1117F-0011-R10b-SM-GI4VE  RNA:Total RNA  RNASEQ         67350184.0
# GTEX-1117F-0011-R11b-SM-GIN8R  RNA:Total RNA  RNASEQ         99021352.0
# GTEX-1117F-0011-R2b-SM-GI4VL   RNA:Total RNA  RNASEQ        102541796.0
# GTEX-1117F-0011-R3a-SM-GJ3PJ   RNA:Total RNA  RNASEQ         87919278.0
#
#                                    SMALTTL     SMALTALG  SMSUPALG SMRDLGTH  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH       367633937.0  232956008.0   72935.0     76.0
# GTEX-1117F-0011-R10b-SM-GI4VE   75528103.0    8050459.0  127460.0     76.0
# GTEX-1117F-0011-R11b-SM-GIN8R  122532321.0   23266593.0  244376.0     76.0
# GTEX-1117F-0011-R2b-SM-GI4VL   126416358.0   23734034.0  140528.0     76.0
# GTEX-1117F-0011-R3a-SM-GJ3PJ   104564329.0   16487319.0  157732.0     76.0
#
#                                   SMVQCFL      SMLMAPQ  ... SMSMRTHQ  \
# sample_id                                               ...
# GTEX-1117F-0005-SM-HL9SH       16433925.0  304143172.0  ...      nan
# GTEX-1117F-0011-R10b-SM-GI4VE   3574302.0   12367264.0  ...      nan
# GTEX-1117F-0011-R11b-SM-GIN8R   4879614.0   33578345.0  ...      nan
# GTEX-1117F-0011-R2b-SM-GI4VL    5688018.0   35903889.0  ...      nan
# GTEX-1117F-0011-R3a-SM-GJ3PJ    3586415.0   24566291.0  ...      nan
#
#                               SMPRERDHQ SMPRERTHQ SMSMGNDT SMPREGNDT SMRDLNMN  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH            nan       nan      nan       nan      nan
# GTEX-1117F-0011-R10b-SM-GI4VE       nan       nan      nan       nan      nan
# GTEX-1117F-0011-R11b-SM-GIN8R       nan       nan      nan       nan      nan
# GTEX-1117F-0011-R2b-SM-GI4VL        nan       nan      nan       nan      nan
# GTEX-1117F-0011-R3a-SM-GJ3PJ        nan       nan      nan       nan      nan
#
#                               SMRDLNMD SMRDLNSD  subject_id      sex    age  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH           nan      nan  GTEX-1117F  unknown  60-69
# GTEX-1117F-0011-R10b-SM-GI4VE      nan      nan  GTEX-1117F  unknown  60-69
# GTEX-1117F-0011-R11b-SM-GIN8R      nan      nan  GTEX-1117F  unknown  60-69
# GTEX-1117F-0011-R2b-SM-GI4VL       nan      nan  GTEX-1117F  unknown  60-69
# GTEX-1117F-0011-R3a-SM-GJ3PJ       nan      nan  GTEX-1117F  unknown  60-69
#
#                               DTHHRDY dataset original_sample_id data_type  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH          4.0    GTEx                      RNA-seq
# GTEX-1117F-0011-R10b-SM-GI4VE     4.0    GTEx                      RNA-seq
# GTEX-1117F-0011-R11b-SM-GIN8R     4.0    GTEx                      RNA-seq
# GTEX-1117F-0011-R2b-SM-GI4VL      4.0    GTEx                      RNA-seq
# GTEX-1117F-0011-R3a-SM-GJ3PJ      4.0    GTEx                      RNA-seq
#
#                               expression_unit species species_ontology  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH                        human   NCBITaxon:9606
# GTEX-1117F-0011-R10b-SM-GI4VE                   human   NCBITaxon:9606
# GTEX-1117F-0011-R11b-SM-GIN8R                   human   NCBITaxon:9606
# GTEX-1117F-0011-R2b-SM-GI4VL                    human   NCBITaxon:9606
# GTEX-1117F-0011-R3a-SM-GJ3PJ                    human   NCBITaxon:9606
#
#                                                         tissue_original  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH                                    Whole Blood
# GTEX-1117F-0011-R10b-SM-GI4VE              Brain - Frontal Cortex (BA9)
# GTEX-1117F-0011-R11b-SM-GIN8R             Brain - Cerebellar Hemisphere
# GTEX-1117F-0011-R2b-SM-GI4VL                   Brain - Substantia nigra
# GTEX-1117F-0011-R3a-SM-GJ3PJ   Brain - Anterior cingulate cortex (BA24)
#
#                               tissue_ontology data_type_original  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH       UBERON:0000178
# GTEX-1117F-0011-R10b-SM-GI4VE  UBERON:0013529
# GTEX-1117F-0011-R11b-SM-GIN8R  UBERON:0002245
# GTEX-1117F-0011-R2b-SM-GI4VL   UBERON:0002038
# GTEX-1117F-0011-R3a-SM-GJ3PJ   UBERON:0009835
#
#                               assay_ontology age_original  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH         EFO:0009922        60-69
# GTEX-1117F-0011-R10b-SM-GI4VE    EFO:0009922        60-69
# GTEX-1117F-0011-R11b-SM-GIN8R    EFO:0009922        60-69
# GTEX-1117F-0011-R2b-SM-GI4VL     EFO:0009922        60-69
# GTEX-1117F-0011-R3a-SM-GJ3PJ     EFO:0009922        60-69
#
#                               developmental_stage_ontology  \
# sample_id
# GTEX-1117F-0005-SM-HL9SH
# GTEX-1117F-0011-R10b-SM-GI4VE
# GTEX-1117F-0011-R11b-SM-GIN8R
# GTEX-1117F-0011-R2b-SM-GI4VL
# GTEX-1117F-0011-R3a-SM-GJ3PJ
#
#                               tissue_ontology_confidence
# sample_id
# GTEX-1117F-0005-SM-HL9SH                          medium
# GTEX-1117F-0011-R10b-SM-GI4VE                     medium
# GTEX-1117F-0011-R11b-SM-GIN8R                     medium
# GTEX-1117F-0011-R2b-SM-GI4VL                      medium
# GTEX-1117F-0011-R3a-SM-GJ3PJ                      medium
#
# [5 rows x 135 columns]
# OBS Columns: ['SMATSSCR', 'SMCENTER', 'SMPTHNTS', 'rna_integrity_number', 'broad_tissue', 'tissue', 'SMUBRID', 'ischemic_time', 'SMTSPAX', 'array_batch', 'SMNABTCHT', 'SMNABTCHD', 'batch', 'SMGEBTCHD', 'SMGEBTCHT', 'ANALYTE_TYPE', 'SMAFRZE', 'SMGTC', 'SMRDTTL', 'SMALTTL', 'SMALTALG', 'SMSUPALG', 'SMRDLGTH', 'SMVQCFL', 'SMLMAPQ', 'SMUMPRD', 'SMUNPDRD', 'SMMPPD', 'SMMAPRT', 'SMMPPDUN', 'SMUNMPRT', 'SMMPDP', 'SMDPMPRT', 'SMMPPDXG', 'SMMPDPXG', 'SMDPRTXG', 'SMCHMRD', 'SMCHMRT', 'SMMPPDPR', 'SMMPHQRD', 'SMMPHQRT', 'SMMPLQRD', 'SMSPLTRT', 'SME1MPRD', 'SME2MPRD', 'SME1MPRT', 'SME2MPRT', 'SME1MMB', 'SME2MMB', 'SME1TTLB', 'SME2TTLB', 'SME1MMRT', 'SME2MMRT', 'SMTTLMM', 'SMTTLB', 'SMBSMMRT', 'SMESTLBS', 'SMEXNCRD', 'SMEXNCRT', 'SMEXPEFF', 'SMNTRNRD', 'SMNTRNRT', 'SMNTRARD', 'SMNTRART', 'SMNTERRD', 'SMNTERRT', 'SMAMBRD', 'SMAMBRT', 'SMNTEXC', 'SMDSCRT', 'SMEXNCRTHQ', 'SMNTRNRTHQ', 'SMNTRARTHQ', 'SMNTERRTHQ', 'SMAMBRTHQ', 'SME1SNSE', 'SME2SNSE', 'SME1ANTI', 'SME2ANTI', 'SME1PCTS', 'SME2PCTS', 'SMGNSDTC', 'SMRRNARD', 'SMRRNART', 'SMMFLGTH', 'SMSFLGTH', 'SMMDFLGTH', 'SMSMFLGTH', 'SMFGCMN', 'SMFGCSD', 'SMFGCSK', 'SMFGCKT', 'SM3PBMN', 'SM3PBSD', 'SM3PBMD', 'SM3PB25P', 'SM3PB75P', 'SM3PBSDM', 'SM3PBGN', 'SMMDMNCV', 'SMMDCVSD', 'SMMDCVCV', 'SMEXCVMD', 'SMEXCVMAD', 'SMMNCV', 'SMUVCRD', 'SMUVCRT', 'SMSHRTRD', 'SMSHRTRT', 'SMSMRDHQ', 'SMSMRTHQ', 'SMPRERDHQ', 'SMPRERTHQ', 'SMSMGNDT', 'SMPREGNDT', 'SMRDLNMN', 'SMRDLNMD', 'SMRDLNSD', 'subject_id', 'sex', 'age', 'DTHHRDY', 'dataset', 'original_sample_id', 'data_type', 'expression_unit', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence']
#
# OBS Dtypes:
#  category    14
# category     5
# object       2
# category     2
# category     2
#             ..
# category     1
# category     1
# category     1
# category     1
# category     1
# Name: count, Length: 114, dtype: int64
#
# VAR (head):
#                          gene_id        original_ids gene_name  \
# ENSG00000000003  ENSG00000000003  ENSG00000000003.15    TSPAN6
# ENSG00000000005  ENSG00000000005   ENSG00000000005.6      TNMD
# ENSG00000000419  ENSG00000000419  ENSG00000000419.14      DPM1
# ENSG00000000457  ENSG00000000457  ENSG00000000457.14     SCYL3
# ENSG00000000460  ENSG00000000460  ENSG00000000460.17  C1orf112
#
#                       gene_type chromosome     mapping_source  \
# ENSG00000000003  protein_coding       chrX  reference_mapping
# ENSG00000000005  protein_coding       chrX  reference_mapping
# ENSG00000000419  protein_coding      chr20  reference_mapping
# ENSG00000000457  protein_coding       chr1  reference_mapping
# ENSG00000000460  protein_coding       chr1  reference_mapping
#
#                 original_gene_id       ensembl_id mapping_confidence
# ENSG00000000003  ENSG00000000003  ENSG00000000003               high
# ENSG00000000005  ENSG00000000005  ENSG00000000005               high
# ENSG00000000419  ENSG00000000419  ENSG00000000419               high
# ENSG00000000457  ENSG00000000457  ENSG00000000457               high
# ENSG00000000460  ENSG00000000460  ENSG00000000460               high
# VAR Columns: ['gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'original_gene_id', 'ensembl_id', 'mapping_confidence']
#
# VAR Dtypes:
#  object      4
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# UNS Keys: ['dataset_info', 'dataset_version', 'gencode_version', 'gene_mapping_stats', 'harmonized_gencode_version', 'harmonized_reference_genome', 'metadata_sources']
#   UNS['metadata_sources'] type: <class 'numpy.ndarray'>
#   UNS['dataset_info'] type: <class 'dict'>
#   UNS['dataset_info'] (snippet): {'data_type': 'RNA-seq', 'expression_unit': 'TPM', 'gencode_version': np.int64(24), 'genes': np.int64(58988), 'samples': np.int64(19616), 'source': 'GTEx', 'subject_count': np.int64(946), 'tissue_coun...
#
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/preprocessed_data/run_20250501_045924/mage_standardized_preprocessed.h5ad ---
# Successfully loaded. Shape: (731, 19428)
#
# --- Inspecting MAGE Preprocessed (Stage 2.5 Output) ---
# Shape: (731, 19428)
#
# OBS (head):
#                        sample_id donor_id subject_id       tissue dataset  \
# _sample_id
# NA06985_NA06985  NA06985_NA06985  NA06985    NA06985  lymphoblast    MAGE
# NA07000_NA07000  NA07000_NA07000  NA07000    NA07000  lymphoblast    MAGE
# NA11919_NA11919  NA11919_NA11919  NA11919    NA11919  lymphoblast    MAGE
# NA11930_NA11930  NA11930_NA11930  NA11930    NA11930  lymphoblast    MAGE
# NA11932_NA11932  NA11932_NA11932  NA11932    NA11932  lymphoblast    MAGE
#
#                 data_type expression_unit is_gencode is_ensembl      sex age  \
# _sample_id
# NA06985_NA06985   rna-seq             TPM      False       True  unknown
# NA07000_NA07000   rna-seq             TPM      False       True  unknown
# NA11919_NA11919   rna-seq             TPM      False       True  unknown
# NA11930_NA11930   rna-seq             TPM      False       True  unknown
# NA11932_NA11932   rna-seq             TPM      False       True  unknown
#
#                 species species_ontology tissue_original tissue_ontology  \
# _sample_id
# NA06985_NA06985   human   NCBITaxon:9606     lymphoblast
# NA07000_NA07000   human   NCBITaxon:9606     lymphoblast
# NA11919_NA11919   human   NCBITaxon:9606     lymphoblast
# NA11930_NA11930   human   NCBITaxon:9606     lymphoblast
# NA11932_NA11932   human   NCBITaxon:9606     lymphoblast
#
#                 data_type_original assay_ontology age_original  \
# _sample_id
# NA06985_NA06985            RNA-seq    EFO:0009922
# NA07000_NA07000            RNA-seq    EFO:0009922
# NA11919_NA11919            RNA-seq    EFO:0009922
# NA11930_NA11930            RNA-seq    EFO:0009922
# NA11932_NA11932            RNA-seq    EFO:0009922
#
#                 developmental_stage_ontology tissue_ontology_confidence
# _sample_id
# NA06985_NA06985                                                    none
# NA07000_NA07000                                                    none
# NA11919_NA11919                                                    none
# NA11930_NA11930                                                    none
# NA11932_NA11932                                                    none
# OBS Columns: ['sample_id', 'donor_id', 'subject_id', 'tissue', 'dataset', 'data_type', 'expression_unit', 'is_gencode', 'is_ensembl', 'sex', 'age', 'species', 'species_ontology', 'tissue_original', 'tissue_ontology', 'data_type_original', 'assay_ontology', 'age_original', 'developmental_stage_ontology', 'tissue_ontology_confidence']
#
# OBS Dtypes:
#  category    4
# object      3
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# VAR (head):
#                          gene_id        original_ids gene_name  \
# ENSG00000000003  ENSG00000000003  ENSG00000000003.14    TSPAN6
# ENSG00000000419  ENSG00000000419  ENSG00000000419.12      DPM1
# ENSG00000000457  ENSG00000000457  ENSG00000000457.13     SCYL3
# ENSG00000000460  ENSG00000000460  ENSG00000000460.16  C1orf112
# ENSG00000000938  ENSG00000000938  ENSG00000000938.12       FGR
#
#                       gene_type chromosome     mapping_source  \
# ENSG00000000003  protein_coding       chrX  reference_mapping
# ENSG00000000419  protein_coding      chr20  reference_mapping
# ENSG00000000457  protein_coding       chr1  reference_mapping
# ENSG00000000460  protein_coding       chr1  reference_mapping
# ENSG00000000938  protein_coding       chr1  reference_mapping
#
#                 original_gene_id       ensembl_id mapping_confidence
# ENSG00000000003  ENSG00000000003  ENSG00000000003               high
# ENSG00000000419  ENSG00000000419  ENSG00000000419               high
# ENSG00000000457  ENSG00000000457  ENSG00000000457               high
# ENSG00000000460  ENSG00000000460  ENSG00000000460               high
# ENSG00000000938  ENSG00000000938  ENSG00000000938               high
# VAR Columns: ['gene_id', 'original_ids', 'gene_name', 'gene_type', 'chromosome', 'mapping_source', 'original_gene_id', 'ensembl_id', 'mapping_confidence']
#
# VAR Dtypes:
#  object      4
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# UNS Keys: ['dataset_info', 'gene_mapping_stats']
#   UNS['dataset_info'] type: <class 'dict'>
#   UNS['dataset_info'] (snippet): {'accession': 'PRJNA851328', 'cell_type': 'lymphoblastoid cell lines', 'continental_groups': np.int64(5), 'data_repository': array(['', ''], dtype=object)}...

# %%
# Cell 5: Inspect Final Combined Dataset
adata_combined = load_h5ad_safe(COMBINED_FILE)
inspect_adata(adata_combined, "Combined Dataset (Final Output)")

# Specific checks for combined dataset
if adata_combined:
    print("\n--- Combined Dataset Specific Checks ---")
    if 'dataset' in adata_combined.obs.columns:
        print("\nDataset Value Counts:")
        print(adata_combined.obs['dataset'].value_counts())
    else:
        print("\nERROR: 'dataset' column missing in combined obs!")

    if 'present_in_datasets' in adata_combined.var.columns:
         print("\nGene presence sample (first 5):")
         print(adata_combined.var['present_in_datasets'].head())
    else:
         print("\nERROR: 'present_in_datasets' column missing in combined var!")

    print("\nCombined UNS Keys:", list(adata_combined.uns.keys()))
    # Check structure of specific UNS keys if needed
    # print(adata_combined.uns.get('dataset_info'))
    # print(adata_combined.uns.get('dataset_overlap'))
# Out:
# --- Loading: /mnt/czi-sci-ai/intrinsic-variation-gene-ex/rnaseq/standardized_data/run_20250501_045924/combined_all_genes_sparse_standardized.h5ad ---
# Successfully loaded. Shape: (21004, 62324)
#
# --- Inspecting Combined Dataset (Final Output) ---
# Shape: (21004, 62324)
#
# OBS (head):
#                                                                          sample_id  \
# 002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413_002_S_0413_gencode_v24_pruned
# 002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729_002_S_0729_gencode_v24_pruned
# 002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155_002_S_1155_gencode_v24_pruned
# 002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261_002_S_1261_gencode_v24_pruned
# 002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268_002_S_1268_gencode_v24_pruned
#
#                                           subject_id dataset   data_type  \
# 002_S_0413_002_S_0413_gencode_v24_pruned  002_S_0413    adni  Microarray
# 002_S_0729_002_S_0729_gencode_v24_pruned  002_S_0729    adni  Microarray
# 002_S_1155_002_S_1155_gencode_v24_pruned  002_S_1155    adni  Microarray
# 002_S_1261_002_S_1261_gencode_v24_pruned  002_S_1261    adni  Microarray
# 002_S_1268_002_S_1268_gencode_v24_pruned  002_S_1268    adni  Microarray
#
#                                                expression_unit tissue  \
# 002_S_0413_002_S_0413_gencode_v24_pruned  Normalized intensity  blood
# 002_S_0729_002_S_0729_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1155_002_S_1155_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1261_002_S_1261_gencode_v24_pruned  Normalized intensity  blood
# 002_S_1268_002_S_1268_gencode_v24_pruned  Normalized intensity  blood
#
#                                               sex age
# 002_S_0413_002_S_0413_gencode_v24_pruned  unknown
# 002_S_0729_002_S_0729_gencode_v24_pruned  unknown
# 002_S_1155_002_S_1155_gencode_v24_pruned  unknown
# 002_S_1261_002_S_1261_gencode_v24_pruned  unknown
# 002_S_1268_002_S_1268_gencode_v24_pruned  unknown
# OBS Columns: ['sample_id', 'subject_id', 'dataset', 'data_type', 'expression_unit', 'tissue', 'sex', 'age']
#
# OBS Dtypes:
#  object      1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# VAR (head):
#                          gene_id    present_in_datasets chromosome  \
# ENSG00000000003  ENSG00000000003         adni,gtex,mage       chrX
# ENSG00000000005  ENSG00000000005              adni,gtex       chrX
# ENSG00000000419  ENSG00000000419         adni,gtex,mage      chr20
# ENSG00000000457  ENSG00000000457  adni,encode,gtex,mage       chr1
# ENSG00000000460  ENSG00000000460       encode,gtex,mage       chr1
#
#                     mapping_source gene_name     original_ids       gene_type
# ENSG00000000003  reference_mapping    TSPAN6  ENSG00000000003  protein_coding
# ENSG00000000005  reference_mapping      TNMD  ENSG00000000005  protein_coding
# ENSG00000000419  reference_mapping      DPM1  ENSG00000000419  protein_coding
# ENSG00000000457  reference_mapping     SCYL3  ENSG00000000457  protein_coding
# ENSG00000000460  reference_mapping  C1orf112  ENSG00000000460  protein_coding
# VAR Columns: ['gene_id', 'present_in_datasets', 'chromosome', 'mapping_source', 'gene_name', 'original_ids', 'gene_type']
#
# VAR Dtypes:
#  object      2
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64
#
# UNS Keys: ['dataset_info', 'dataset_overlap', 'gene_counts', 'harmonized_gencode_version', 'harmonized_reference_genome', 'sparsity_stats']
#   UNS['dataset_info'] type: <class 'dict'>
#   UNS['dataset_info'] (snippet): {'approach': 'all_genes_sparse', 'creation_date': '2025-05-01', 'datasets_combined': array(['adni', 'encode', 'gtex', 'mage'], dtype=object), 'description': 'Combined dataset containing all genes from...
#
# --- Combined Dataset Specific Checks ---
#
# Dataset Value Counts:
# dataset
# gtex      19616
# mage        731
# adni        650
# encode        7
# Name: count, dtype: int64
#
# Gene presence sample (first 5):
# ENSG00000000003           adni,gtex,mage
# ENSG00000000005                adni,gtex
# ENSG00000000419           adni,gtex,mage
# ENSG00000000457    adni,encode,gtex,mage
# ENSG00000000460         encode,gtex,mage
# Name: present_in_datasets, dtype: category
# Categories (15, object): ['adni', 'adni,encode', 'adni,encode,gtex', 'adni,encode,gtex,mage', ..., 'encode,mage', 'gtex', 'gtex,mage', 'mage']
#
# Combined UNS Keys: ['dataset_info', 'dataset_overlap', 'gene_counts', 'harmonized_gencode_version', 'harmonized_reference_genome', 'sparsity_stats']
